# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder
import pickle

# %% [markdown]
# # **Load Dataset**

# %%
df_raw = pd.read_csv('../Real_Estate_Sales_2001-2020_GL.csv')
df_raw.head()
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020     9/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500     325000.0       0.4630    Commercial              Nan
# 1          253000     430000.0       0.5883   Residential    Single Family
# 2          130400     179900.0       0.7248   Residential            Condo
# 3          619290     890000.0       0.6958   Residential    Single Family
# 4          862330    1447500.0       0.5957   Residential    Single Family
#
#    Years until sold
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 1

# %% [markdown]
# ### Data is from Kaggel.com [Real Estate Sales 2001-2020](https://www.kaggle.com/datasets/derrekdevon/real-estate-sales-2001-2020)
#
# | Attribute | Description|
# | -------- | -------- |
# |**Serial Number**| Is just a unique set of digits to identify each transaction.|
# |**List year**| This is the year that the particular property was put up for sale.|
# |**Date Recorded**| Is the date that the transaction was completed. That is, the year the property was bought.|
# |**Town**| The town where this property is located.|
# |**Address**| The property's address.|
# |**Assessed Value**| How much the property is generally considered to be worth.|
# |**Sale Amount**| How much the property was actually sold for.|
# |**Sales Ratio**| The ratio measures how close the selling price of the property is to it's assessed value.|
# |**Property Type**| What kind of property it is.|
# |**Residential Type**| If it is a residential property, what type is it.|
# |**Years until sold**| Number of years before the property was finally sold.|

# %%
df_raw.dropna(inplace=True)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997213 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997213 non-null  object
#  5   Assessed Value    997213 non-null  int64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     997213 non-null  object
#  9   Residential Type  997213 non-null  object
#  10  Years until sold  997213 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.7+ MB

# %%
# convert date recorded values into date type data
df_raw['Date Recorded'] = pd.to_datetime(df_raw['Date Recorded'], format='%m/%d/%Y')

# %%
# check for duplicates from all columns
df_raw.duplicated().any()
# Out:
# False

# %%
# check for duplicates from selected columns
df_raw.duplicated(subset=['List Year','Address','Date Recorded','Years until sold']).any()
# Out:
# True

# %%
# it appears that some of the data are inconsistent because a property had multiple transactions within the same date with different assessed value, sale amount, and sale ratio
df_filtered = df_raw.drop_duplicates(subset=['List Year', 'Town', 'Address','Years until sold']).copy()

# %%
df_filtered.replace('Nan', pd.NA, inplace=True)
df_filtered.isna().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            0
# Town                     0
# Address                 30
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type       361920
# Residential Type    367511
# Years until sold         0
# dtype: int64

# %%
df_filtered.describe()
# Out:
#        Serial Number      List Year                  Date Recorded  \
# count   9.617280e+05  961728.000000                         961728
# mean    4.384073e+05    2010.269882  2011-07-18 10:20:55.939309056
# min     8.100000e+01    2001.000000            1999-04-05 00:00:00
# 25%     3.049000e+04    2004.000000            2005-08-11 00:00:00
# 50%     7.047400e+04    2010.000000            2011-04-05 00:00:00
# 75%     1.600270e+05    2016.000000            2017-05-01 00:00:00
# max     2.000500e+09    2020.000000            2021-09-30 00:00:00
# std     6.630297e+06       6.230102                            NaN
#
#        Assessed Value   Sale Amount   Sales Ratio  Years until sold
# count    9.617280e+05  9.617280e+05  9.617280e+05     961728.000000
# mean     2.722324e+05  3.951550e+05  8.617711e+00          0.748400
# min      0.000000e+00  0.000000e+00  0.000000e+00        -18.000000
# 25%      8.820000e+04  1.430000e+05  4.866885e-01          0.000000
# 50%      1.388100e+05  2.276000e+05  6.226667e-01          1.000000
# 75%      2.256000e+05  3.650235e+05  7.770370e-01          1.000000
# max      8.815100e+08  5.000000e+09  1.226420e+06          4.000000
# std      1.613109e+06  5.437774e+06  1.696516e+03          0.436258

# %% [markdown]
# # **Data Cleaning for Numeric Data**

# %% [markdown]
# #### From the description about the data above, we can infer that there is inconsistent value in the 'Years until sold' column. It is not possible to have a negative value.

# %%
df_filtered.loc[:, 'Years until sold'] = df_filtered['Date Recorded'].dt.year - df_filtered['List Year']

# %%
neg_years_until_sold = df_filtered[df_filtered['Years until sold'] < 0].shape[0]
print(f'Total negative values for "Years until sold" column: {neg_years_until_sold}')
# Out:
# Total negative values for "Years until sold" column: 56

# %%
# create new dataframe which consist only positive value for the "Years until sold" column
df1 = df_filtered.copy()
df1 = df1[df1['Years until sold'] >= 0]

# to make sure all values in "Years until sold" column are valid, I'm going to recalculate all the values by substracting list year and the year from date recorded
df1['Years until sold'] = df1['Date Recorded'].dt.year - df1['List Year']

# %%
df1.describe()
# Out:
#        Serial Number      List Year                  Date Recorded  \
# count   9.616720e+05  961672.000000                         961672
# mean    4.384235e+05    2010.269684  2011-07-18 10:58:07.485961472
# min     8.100000e+01    2001.000000            2001-10-01 00:00:00
# 25%     3.049000e+04    2004.000000            2005-08-11 00:00:00
# 50%     7.047300e+04    2010.000000            2011-04-05 00:00:00
# 75%     1.600270e+05    2016.000000            2017-05-01 00:00:00
# max     2.000500e+09    2020.000000            2021-09-30 00:00:00
# std     6.630489e+06       6.230115                            NaN
#
#        Assessed Value   Sale Amount   Sales Ratio  Years until sold
# count    9.616720e+05  9.616720e+05  9.616720e+05     961672.000000
# mean     2.722355e+05  3.951581e+05  8.618162e+00          0.748671
# min      0.000000e+00  0.000000e+00  0.000000e+00          0.000000
# 25%      8.820000e+04  1.430000e+05  4.866778e-01          0.000000
# 50%      1.388100e+05  2.276000e+05  6.226598e-01          1.000000
# 75%      2.256000e+05  3.650425e+05  7.770369e-01          1.000000
# max      8.815100e+08  5.000000e+09  1.226420e+06          4.000000
# std      1.613154e+06  5.437931e+06  1.696565e+03          0.433833

# %% [markdown]
# #### Based on the newest description above, there are some anomalies in the minimum and maximum value for assessed value, sale amount, and sales ratio
#
# #### Therefore, I want to find total rows that consist of 0 value in at least 1 out of 3 criteria: assessed value, sale amount, and sales ratio

# %%
# display all rows with 0 value with these criteria
zero_assessed_value = df1[df1['Assessed Value']==0].shape[0]
zero_sale_amount = df1[df1['Sale Amount']==0].shape[0]
zero_sales_ratio = df1[df1['Sales Ratio']==0].shape[0]

print(f'''
Total data with 0 value of assessed value: {zero_assessed_value}
Total data with 0 value of sale amount: {zero_sale_amount}
Total data with 0 value of sales ratio: {zero_sales_ratio}
''')
# Out:
# Total data with 0 value of assessed value: 6427
# Total data with 0 value of sale amount: 1575
# Total data with 0 value of sales ratio: 7771

# %%
df1[(df1['Assessed Value'] == 0)
           | (df1['Sale Amount'] == 0)
           | (df1['Sales Ratio'] == 0)].head()
# Out:
#      Serial Number  List Year Date Recorded       Town           Address  \
# 75           10323       2001    2002-09-23   Coventry   400 EASTVIEW DR
# 86           10045       2001    2002-01-03    Bethany      9 SIMPSON CT
# 96           12532       2001    2002-08-13     Bolton      45 BEACON CT
# 127          10055       2001    2001-12-04   Stafford    15 JENNIFER LN
# 133          10502       2001    2002-01-15  Stratford  1101 SUCCESS AVE
#
#      Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 75                0     325400.0          0.0          <NA>             <NA>
# 86            96590          0.0          0.0          <NA>             <NA>
# 96                0      12350.0          0.0          <NA>             <NA>
# 127               0     165155.0          0.0          <NA>             <NA>
# 133               0      50000.0          0.0          <NA>             <NA>
#
#      Years until sold
# 75                  1
# 86                  1
# 96                  1
# 127                 0
# 133                 1

# %% [markdown]
# #### From the previous insight, we can conclude that all zero values in the Sales Ratio column happened mostly because there is zero value in the Assessed Value or Sale Amount column

# %% [markdown]
# #### After scouring the internet, I got some insight regarding the property price and assessment sales ratio:
# 1. Based on the property price on [landsearch.com](https://www.landsearch.com/), the cheapest property catalog is over $100.
# 2. According to [iaao.org](https://www.iaao.org/media/standards/Standard_on_Ratio_Studies.pdf), property assessment sales ratio is between 90% - 110%
#
# #### Therefore, there are several steps I would do:
# 1. I will filter out all rows that have assessed value and sale amount less than 100 and assign the dataframe into a new variable
# 2. I will assume that the assessed value and sale amount have either the same number of digits or a maximum difference of 1 digit between them since I got no extra information on the internet to adjust them better.
# 3. While adjusting the assessed value or the sale amound digit, I will ensure that the Sales Ratio is between 0.2 and 8
#
# #### Assumptions:
# 1. Assessed Value and Sale Amount have either the same number of digits or a maximum difference of 1 digit.
# 2. Sales Ratio below 0.2 is considered invalid because it is way too overprice.
# 3. Sales Ratio above 8 is considered invalid because it is way too underprice.

# %%
# filter out all rows that have assign value and sale amount less than 100 and assign the dataframe into a new variable
df1_assessed_and_sale_above0 = df1.copy()
df1_assessed_and_sale_above0 = df1[(df1['Sale Amount'] > 0) & (df1['Assessed Value'] > 0)].sort_values(by='Assessed Value', ascending=True)

# %%
def adjust_assessed_and_sale_digits(data):
    for index,row in data.iterrows():
        assessed_value = row['Assessed Value']
        sale_amount = row['Sale Amount']

        assessed_value_digits = len(str(assessed_value))
        sale_amount_digits = len(str(int(sale_amount)))

        diff = abs(assessed_value_digits - sale_amount_digits)
        # Adjustments
        if diff > 1:
            if assessed_value_digits > sale_amount_digits:
                sale_amount *= (10**diff)
            elif assessed_value_digits < sale_amount_digits:
                assessed_value *= (10**diff)

        # Recalculate sales ratio before making adjustments
        sales_ratio = assessed_value / sale_amount

        # Check and adjust sales ratio if it's not within the desired range
        while sales_ratio < 0.2 or sales_ratio > 8:
            if sales_ratio < 0.2:
                assessed_value *= 10
            elif sales_ratio > 8:
                sale_amount *= 10
            
            # Recalculate sales ratio after adjustments
            sales_ratio = assessed_value / sale_amount
        
        # Update values in the DataFrame using at
        data.at[index, 'Sale Amount'] = sale_amount
        data.at[index, 'Assessed Value'] = int(assessed_value)
        data.at[index, 'Sales Ratio'] = round(sales_ratio, 5)

# %%
# Iterate each row to ensure the sales amount digits are equal or equal+1 with the assessed value, and vice versa
adjust_assessed_and_sale_digits(df1_assessed_and_sale_above0)

# %%
df1_assessed_and_sale_above0.describe()
# Out:
#        Serial Number      List Year                  Date Recorded  \
# count   9.539040e+05  953904.000000                         953904
# mean    4.402985e+05    2010.304968  2011-07-31 08:35:16.922457856
# min     8.100000e+01    2001.000000            2001-10-01 00:00:00
# 25%     3.050200e+04    2004.000000            2005-08-19 00:00:00
# 50%     7.060200e+04    2010.000000            2011-05-06 00:00:00
# 75%     1.600420e+05    2016.000000            2017-05-09 00:00:00
# max     2.000500e+09    2020.000000            2021-09-30 00:00:00
# std     6.651574e+06       6.227816                            NaN
#
#        Assessed Value   Sale Amount    Sales Ratio  Years until sold
# count    9.539040e+05  9.539040e+05  953904.000000     953904.000000
# mean     3.220957e+05  4.471217e+05       0.760660          0.748762
# min      1.400000e+02  1.000000e+02       0.200000          0.000000
# 25%      9.327000e+04  1.450000e+05       0.503140          0.000000
# 50%      1.443400e+05  2.300000e+05       0.634790          1.000000
# 75%      2.368100e+05  3.700000e+05       0.796800          1.000000
# max      2.238530e+09  5.000000e+09       8.000000          4.000000
# std      3.397089e+06  5.686204e+06       0.581548          0.433781

# %% [markdown]
# #### For the next step, I will handle the rows that have value equal to 0 in either the Assessed Value or Sale Amount column, but exceeds 0 in one of them.

# %%
# get all rows that have value equal to 0 in either the Assessed Value or Sale Amount column, but exceeds 0 in one of them.
df1_assessed_or_sale_eq0 = df1.copy()
df1_assessed_or_sale_eq0 = df1[(((df1['Sale Amount'] == 0) & (df1['Assessed Value'] > 0))) 
                               | (((df1['Sale Amount'] > 0) & (df1['Assessed Value'] == 0)))]
df1_assessed_or_sale_eq0.head()
# Out:
#      Serial Number  List Year Date Recorded       Town           Address  \
# 75           10323       2001    2002-09-23   Coventry   400 EASTVIEW DR
# 86           10045       2001    2002-01-03    Bethany      9 SIMPSON CT
# 96           12532       2001    2002-08-13     Bolton      45 BEACON CT
# 127          10055       2001    2001-12-04   Stafford    15 JENNIFER LN
# 133          10502       2001    2002-01-15  Stratford  1101 SUCCESS AVE
#
#      Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 75                0     325400.0          0.0          <NA>             <NA>
# 86            96590          0.0          0.0          <NA>             <NA>
# 96                0      12350.0          0.0          <NA>             <NA>
# 127               0     165155.0          0.0          <NA>             <NA>
# 133               0      50000.0          0.0          <NA>             <NA>
#
#      Years until sold
# 75                  1
# 86                  1
# 96                  1
# 127                 0
# 133                 1

# %%
# margin of error for adjusting the sales ratio
z = 1.96 # confidence level 95%
std = df1_assessed_and_sale_above0['Sales Ratio'].std()
n = df1_assessed_or_sale_eq0.shape[0]

# margin of error formula: z * (standard deviation / sqrt(sample size))
moe = z * (std/(n**(1/2)))
moe
# Out:
# 0.013131942941407175

# %%
# adjust the sales ratio 
for index,row in df1_assessed_or_sale_eq0.iterrows():
    # variable initiation
    assessed_value = row['Assessed Value']
    sale_amount = row['Sale Amount']
    sales_ratio = round(random.uniform(0.9-moe,1.1+moe),5)
    
    # replace 0 value in the Assessed Value and/or Sale Amount column
    if assessed_value < 100:
        assessed_value = sales_ratio * sale_amount
    elif sale_amount < 100:
        sale_amount = assessed_value / sales_ratio

    df1_assessed_or_sale_eq0.loc[index, 'Sale Amount'] = sale_amount
    df1_assessed_or_sale_eq0.loc[index, 'Assessed Value'] = int(assessed_value)
    df1_assessed_or_sale_eq0.loc[index, 'Sales Ratio'] = sales_ratio

# %% [markdown]
# To finish the numeric data cleaning, I will concatenat df1_assessed_or_sale_eq0 and df1_assessed_and_sale_above0

# %%
df1_assessed_and_sale_above0_done = pd.concat([df1_assessed_and_sale_above0,df1_assessed_or_sale_eq0])

# %%
df1_assessed_and_sale_above0_done.describe()
# Out:
#        Serial Number      List Year                  Date Recorded  \
# count   9.614380e+05  961438.000000                         961438
# mean    4.385210e+05    2010.271386  2011-07-19 01:47:30.447767040
# min     8.100000e+01    2001.000000            2001-10-01 00:00:00
# 25%     3.049000e+04    2004.000000            2005-08-12 00:00:00
# 50%     7.047850e+04    2010.000000            2011-04-06 00:00:00
# 75%     1.600280e+05    2016.000000            2017-05-01 00:00:00
# max     2.000500e+09    2020.000000            2021-09-30 00:00:00
# std     6.631293e+06       6.229872                            NaN
#
#        Assessed Value   Sale Amount    Sales Ratio  Years until sold
# count    9.614380e+05  9.614380e+05  961438.000000     961438.000000
# mean     3.220990e+05  4.461486e+05       0.762534          0.748659
# min      0.000000e+00  0.000000e+00       0.200000          0.000000
# 25%      9.319000e+04  1.450000e+05       0.504182          0.000000
# 50%      1.444800e+05  2.300000e+05       0.636790          1.000000
# 75%      2.374000e+05  3.700000e+05       0.803080          1.000000
# max      2.238530e+09  5.000000e+09       8.000000          4.000000
# std      3.385409e+06  5.664977e+06       0.579677          0.433840

# %% [markdown]
# #### Next, I will do feature engineering to replace 0 values in both Assessed Value and Sale Amount columns

# %%
df1_assessed_and_sale_eq0 = df1[(df1['Assessed Value']==0) & (df1['Sale Amount']==0)].copy()
df1_assessed_and_sale_eq0.head()
# Out:
#        Serial Number  List Year Date Recorded        Town           Address  \
# 41139          39004       2003    2003-10-21      Easton      15 FENSKY RD
# 65969          30102       2003    2004-06-09   Thomaston  76 LITCHFIELD ST
# 66842          30130       2003    2004-06-24   Thomaston    26-28 GROVE ST
# 66848          39999       2003    2004-02-02  West Haven              <NA>
# 66878          49888       2004    2005-07-12  Bridgeport   1650 RESERVOUIR
#
#        Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 41139               0          0.0          0.0          <NA>
# 65969               0          0.0          0.0          <NA>
# 66842               0          0.0          0.0          <NA>
# 66848               0          0.0          0.0          <NA>
# 66878               0          0.0          0.0          <NA>
#
#       Residential Type  Years until sold
# 41139             <NA>                 0
# 65969             <NA>                 1
# 66842             <NA>                 1
# 66848             <NA>                 1
# 66878             <NA>                 1

# %%
def random_sample_impute(data, feature):
    random_sample = df1_assessed_and_sale_above0_done[feature].sample(data.shape[0], random_state=0)
    random_sample.index = data[feature].index
    data.loc[:, feature] = random_sample

# %%
# impute 0 values for the Assessed Value column
random_sample_impute(df1_assessed_and_sale_eq0, 'Assessed Value')

# impute 0 values for the Sale Amount column
random_sample_impute(df1_assessed_and_sale_eq0, 'Sale Amount')

# %%
# Iterate each row to ensure the sales amount digits are equal or equal+1 with the assessed value, and vice versa
adjust_assessed_and_sale_digits(df1_assessed_and_sale_eq0)

# %%
df1_assessed_and_sale_eq0.head()
# Out:
#        Serial Number  List Year Date Recorded        Town           Address  \
# 41139          39004       2003    2003-10-21      Easton      15 FENSKY RD
# 65969          30102       2003    2004-06-09   Thomaston  76 LITCHFIELD ST
# 66842          30130       2003    2004-06-24   Thomaston    26-28 GROVE ST
# 66848          39999       2003    2004-02-02  West Haven              <NA>
# 66878          49888       2004    2005-07-12  Bridgeport   1650 RESERVOUIR
#
#        Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 41139          235000     450000.0      0.52222          <NA>
# 65969          169890     265000.0      0.64109          <NA>
# 66842           99490     150000.0      0.66327          <NA>
# 66848          292700     292500.0      1.00068          <NA>
# 66878          100080     180000.0      0.55600          <NA>
#
#       Residential Type  Years until sold
# 41139             <NA>                 0
# 65969             <NA>                 1
# 66842             <NA>                 1
# 66848             <NA>                 1
# 66878             <NA>                 1

# %%
df1_numeric_clean = pd.concat([df1_assessed_and_sale_above0_done,df1_assessed_and_sale_eq0])

# %%
df1_numeric_clean.describe()
# Out:
#        Serial Number      List Year                  Date Recorded  \
# count   9.616720e+05  961672.000000                         961672
# mean    4.384235e+05    2010.269684  2011-07-18 10:58:07.485961984
# min     8.100000e+01    2001.000000            2001-10-01 00:00:00
# 25%     3.049000e+04    2004.000000            2005-08-11 00:00:00
# 50%     7.047300e+04    2010.000000            2011-04-05 00:00:00
# 75%     1.600270e+05    2016.000000            2017-05-01 00:00:00
# max     2.000500e+09    2020.000000            2021-09-30 00:00:00
# std     6.630489e+06       6.230115                            NaN
#
#        Assessed Value   Sale Amount    Sales Ratio  Years until sold
# count    9.616720e+05  9.616720e+05  961672.000000     961672.000000
# mean     3.220757e+05  4.461258e+05       0.762525          0.748671
# min      0.000000e+00  0.000000e+00       0.200000          0.000000
# 25%      9.319000e+04  1.450000e+05       0.504180          0.000000
# 50%      1.444800e+05  2.300000e+05       0.636790          1.000000
# 75%      2.374000e+05  3.700000e+05       0.803072          1.000000
# max      2.238530e+09  5.000000e+09       8.000000          4.000000
# std      3.385001e+06  5.664292e+06       0.579659          0.433833

# %% [markdown]
# # **Data Cleaning for String Data**

# %%
df2 = df1_numeric_clean.copy()

# %%
df2.isna().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            0
# Town                     0
# Address                 30
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type       361915
# Residential Type    367506
# Years until sold         0
# dtype: int64

# %%
df2['Property Type'].value_counts()
# Out:
# Property Type
# Single Family     391276
# Condo             103444
# Residential        59694
# Two Family         25521
# Three Family       12129
# Vacant Land         2944
# Four Family         2102
# Commercial          1938
# Apartments           479
# Industrial           226
# Public Utility         4
# Name: count, dtype: int64

# %%
df2['Residential Type'].value_counts()
# Out:
# Residential Type
# Single Family    433885
# Condo            115658
# Two Family        28665
# Three Family      13596
# Four Family        2362
# Name: count, dtype: int64

# %% [markdown]
# #### Based on the insight about property types and the research I did on study.com, I've decided to devide the property types into 5 groups:
# 1. Residential (Singe Family, Multi-Family, Condo, Apartment)
# 2. Industrial
# 3. Commercial
# 4. Public Utility
# 5. Vacant Land

# %%
# Update the residential type based on conditions
conditions = df2['Property Type'].isin(['Single Family', 'Two Family', 'Three Family', 'Four Family', 'Condo', 'Apartments'])
df2.loc[conditions, 'Residential Type'] = df2.loc[conditions, 'Property Type']


df2['Residential Type'].value_counts()
# Out:
# Residential Type
# Single Family    433885
# Condo            115658
# Two Family        28665
# Three Family      13596
# Four Family        2362
# Apartments          479
# Name: count, dtype: int64

# %%
# Update the property type based on conditions
conditions = df2['Property Type'].isin(['Single Family', 'Two Family', 'Three Family', 'Four Family', 'Condo', 'Apartments'])
df2.loc[conditions, 'Property Type'] = 'Residential'


df2['Property Type'].value_counts()
# Out:
# Property Type
# Residential       594645
# Vacant Land         2944
# Commercial          1938
# Industrial           226
# Public Utility         4
# Name: count, dtype: int64

# %%
df2.loc[df2['Address']=='parking space only','Property Type']='Public Utility'

# %% [markdown]
# #### To determine the property type and the residential type, I'm going to use machine learning to classify the data

# %%
df2_ml = df2[['Assessed Value', 'Sale Amount', 'Sales Ratio', 'Years until sold', 'Property Type', 'Residential Type']].copy()
df2_ml.head()
# Out:
#         Assessed Value  Sale Amount  Sales Ratio  Years until sold  \
# 58884             1000       3500.0      0.28571                 1
# 816649         1000000    4150000.0      0.24096                 1
# 678302          100000      80830.0      1.23716                 1
# 719532            1000       4947.0      0.20214                 0
# 470663            1000       4000.0      0.25000                 1
#
#        Property Type Residential Type
# 58884    Vacant Land             <NA>
# 816649          <NA>             <NA>
# 678302   Residential    Single Family
# 719532          <NA>             <NA>
# 470663          <NA>             <NA>

# %%
# filter the dataset from Nan values
df2_ml_not_nan_pt = df2_ml[df2_ml['Property Type'].notna()].drop('Residential Type', axis=1)
df2_ml_not_nan_pt
# Out:
#         Assessed Value  Sale Amount  Sales Ratio  Years until sold  \
# 58884             1000       3500.0      0.28571                 1
# 678302          100000      80830.0      1.23716                 1
# 681182           10000      41680.0      0.23992                 1
# 748599            5000       3125.0      1.60000                 1
# 17155           500000     143995.0      3.47234                 1
# ...                ...          ...          ...               ...
# 992641          385248     360730.0      1.06797                 1
# 994922          374769     418905.0      0.89464                 1
# 996063          222040     230450.0      0.96351                 1
# 996597          527692     482850.0      1.09287                 1
# 996735           90910      85000.0      1.06953                 1
#
#        Property Type
# 58884    Vacant Land
# 678302   Residential
# 681182   Residential
# 748599   Residential
# 17155    Residential
# ...              ...
# 992641   Residential
# 994922   Residential
# 996063   Residential
# 996597   Residential
# 996735   Residential
#
# [599758 rows x 5 columns]

# %% [markdown]
# #### 1. Prediction for Property Type

# %%
def scale_dataset(data, target_column, oversample=False):
    X = data[data.columns[:-1]].values
    y = data[target_column].values

    # scale the feature data to make the value range more reasonable and help the computer learn more efficient
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    # oversampling data to make the data distribution more balance
    if oversample:
        ros = RandomOverSampler()
        X, y = ros.fit_resample(X, y)
    
    
    data = np.hstack([X,y.reshape(-1,1)])

    return data,  X, y

# %%
# split the dataset
pt_train, pt_test = train_test_split(df2_ml_not_nan_pt, test_size=0.6, random_state= 42, shuffle= True)

# %%
# scale and oversample train and test dataset
pt_train, pt_X_train, pt_y_train = scale_dataset(pt_train, 'Property Type', oversample=True)
pt_test, pt_X_test, pt_y_test = scale_dataset(pt_test, 'Property Type', oversample=False)

# %%
# pairplot for property type
sns.pairplot(df2_ml_not_nan_pt, hue= 'Property Type')
plt.show()

# %% [markdown]
# Since the data points that we have are overlapping one another, the kNN model would perform great in this scenario because the kNN model is based on Euclidean Distance, which the model will predict the class of a point based on its nearby points. It's good for situations where different classes mix in the data.

# %%
knn = KNeighborsClassifier()
knn.fit(pt_X_train, pt_y_train) # train knn

# make prediction
pt_y_pred = knn.predict(pt_X_test)

# test set evaluation
report = classification_report(pt_y_test, pt_y_pred)
knn_accuracy_score = accuracy_score(pt_y_test, pt_y_pred)
knn_precision_score = precision_score(pt_y_test, pt_y_pred, average='weighted', zero_division=0)  # Choose the appropriate average
knn_recall_score = recall_score(pt_y_test, pt_y_pred, average='weighted', zero_division=0)  # Choose the appropriate average
knn_f1_score = f1_score(pt_y_test, pt_y_pred, average='weighted', zero_division=0)  # Choose the appropriate average

print('-'*35)
print(f'Accuracy Score: {round(knn_accuracy_score,5)}')
print(f'Precision Score: {round(knn_precision_score,5)}')
print(f'Recall Score: {round(knn_recall_score,5)}')
print(f'F1 Score: {round(knn_f1_score,5)}')
print(f'Labels with no predicted samples: {set(np.unique(pt_y_test)) - set(np.unique(pt_y_pred))}')
print('-'*35)
# Out:
# C:\Users\fredl\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fredl\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fredl\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# -----------------------------------
# Accuracy Score: 0.97336
# Precision Score: 0.98339
# Recall Score: 0.97336
# F1 Score: 0.97833
# Labels with no predicted samples: {'Public Utility'}
# -----------------------------------

# %% [markdown]
# kNN hyperparameter tuning for property type prediction model

# %%
# define the parameters
knn_params = {
    'n_neighbors': range(1,10,2)
}

# grid search
cv = StratifiedKFold(n_splits= 10)
grid_search = GridSearchCV(estimator=knn, param_grid=knn_params, cv=cv, scoring='accuracy', verbose=2)
grid_result = grid_search.fit(pt_X_train, pt_y_train)

# final model and make prediction
final_knn = KNeighborsClassifier(**grid_result.best_params_)
final_knn.fit(pt_X_train, pt_y_train)
pt_y_pred = final_knn.predict(pt_X_test)

# test set evaluation
knn_accuracy_score = accuracy_score(pt_y_test, pt_y_pred)
knn_precision_score = precision_score(pt_y_test, pt_y_pred, average='weighted', zero_division=0)  # Choose the appropriate average
knn_recall_score = recall_score(pt_y_test, pt_y_pred, average='weighted', zero_division=0)  # Choose the appropriate average
knn_f1_score = f1_score(pt_y_test, pt_y_pred, average='weighted', zero_division=0)  # Choose the appropriate average

print('-'*35)
print(f'Accuracy Score: {round(knn_accuracy_score,5)}')
print(f'Precision Score: {round(knn_precision_score,5)}')
print(f'Recall Score: {round(knn_recall_score,5)}')
print(f'F1 Score: {round(knn_f1_score,5)}')
print(f'Labels with no predicted samples: {set(np.unique(pt_y_test)) - set(np.unique(pt_y_pred))}')
print(f'Best parameters: {grid_result.best_params_}')
print('-'*35)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# [CV] END ......................................n_neighbors=1; total time=  39.2s
# [CV] END ......................................n_neighbors=1; total time=  38.6s
# [CV] END ......................................n_neighbors=1; total time=  38.9s
# [CV] END ......................................n_neighbors=1; total time=  38.8s
# [CV] END ......................................n_neighbors=1; total time=  38.7s
# [CV] END ......................................n_neighbors=1; total time=  38.6s
# [CV] END ......................................n_neighbors=1; total time=  38.3s
# [CV] END ......................................n_neighbors=1; total time=  38.8s
# [CV] END ......................................n_neighbors=1; total time=  38.7s
# [CV] END ......................................n_neighbors=1; total time=  38.6s
# [CV] END ......................................n_neighbors=3; total time=  39.4s
# [CV] END ......................................n_neighbors=3; total time=  38.8s
# [CV] END ......................................n_neighbors=3; total time=  39.1s
# [CV] END ......................................n_neighbors=3; total time=  38.9s
# [CV] END ......................................n_neighbors=3; total time=  39.0s
# [CV] END ......................................n_neighbors=3; total time=  38.6s
# [CV] END ......................................n_neighbors=3; total time=  38.8s
# [CV] END ......................................n_neighbors=3; total time=  38.9s
# [CV] END ......................................n_neighbors=3; total time=  38.9s
# [CV] END ......................................n_neighbors=3; total time=  38.8s
# [CV] END ......................................n_neighbors=5; total time=  39.1s
# [CV] END ......................................n_neighbors=5; total time=  39.0s
# [CV] END ......................................n_neighbors=5; total time=  39.4s
# [CV] END ......................................n_neighbors=5; total time=  39.2s
# [CV] END ......................................n_neighbors=5; total time=  39.3s
# [CV] END ......................................n_neighbors=5; total time=  39.1s
# [CV] END ......................................n_neighbors=5; total time=  38.9s
# [CV] END ......................................n_neighbors=5; total time=  39.2s
# [CV] END ......................................n_neighbors=5; total time=  39.3s
# [CV] END ......................................n_neighbors=5; total time=  40.6s
# [CV] END ......................................n_neighbors=7; total time=  39.4s
# [CV] END ......................................n_neighbors=7; total time=  39.1s
# [CV] END ......................................n_neighbors=7; total time=  39.3s
# [CV] END ......................................n_neighbors=7; total time=  39.5s
# [CV] END ......................................n_neighbors=7; total time=  39.4s
# [CV] END ......................................n_neighbors=7; total time=  39.3s
# [CV] END ......................................n_neighbors=7; total time=  39.5s
# [CV] END ......................................n_neighbors=7; total time=  39.4s
# [CV] END ......................................n_neighbors=7; total time=  39.5s
# [CV] END ......................................n_neighbors=7; total time=  39.3s
# [CV] END ......................................n_neighbors=9; total time=  39.5s
# [CV] END ......................................n_neighbors=9; total time=  39.4s
# [CV] END ......................................n_neighbors=9; total time=  39.4s
# [CV] END ......................................n_neighbors=9; total time=  39.4s
# [CV] END ......................................n_neighbors=9; total time=  39.5s
# [CV] END ......................................n_neighbors=9; total time=  39.4s
# [CV] END ......................................n_neighbors=9; total time=  39.4s
# [CV] END ......................................n_neighbors=9; total time=  39.7s
# [CV] END ......................................n_neighbors=9; total time=  40.0s
# [CV] END ......................................n_neighbors=9; total time=  40.4s
# -----------------------------------
# Accuracy Score: 0.97951
# Precision Score: 0.98336
# Recall Score: 0.97951
# F1 Score: 0.98142
# Labels with no predicted samples: {'Public Utility'}
# Best parameters: {'n_neighbors': 3}
# -----------------------------------

# %%
# save knn model
with open('final_knn','wb') as f:
    pickle.dump(final_knn, f)

# %% [markdown]
# Predict the property type of a feature data that have "Nan" value in the Property Type column

# %%
# get all row consisting of "Nan" in the Property Type column
df2_nan_pt_predict = df2_ml[df2_ml['Property Type'].isna()].drop('Residential Type', axis=1).copy()
df2_nan_pt_predict.head()
# Out:
#         Assessed Value  Sale Amount  Sales Ratio  Years until sold  \
# 816649         1000000    4150000.0      0.24096                 1
# 719532            1000       4947.0      0.20214                 0
# 470663            1000       4000.0      0.25000                 1
# 321685          100000     308700.0      0.32394                 1
# 698042           10000      11192.0      0.89350                 0
#
#        Property Type
# 816649          <NA>
# 719532          <NA>
# 470663          <NA>
# 321685          <NA>
# 698042          <NA>

# %%
# load knn model
with open('final_knn', 'rb') as f:
    knn_property_type = pickle.load(f)

# %%
# predict the data using the final_knn model
nan_pt_predict = knn_property_type.predict(df2_nan_pt_predict[df2_nan_pt_predict.columns[:-1]].values)
nan_pt_predict
# Out:
# array(['Residential', 'Residential', 'Residential', ..., 'Residential',
#        'Residential', 'Residential'], dtype=object)

# %%
# update the all the Nan(s) in the Property Type column with the predicted value
df2_nan_pt_predict['Property Type'] = nan_pt_predict.reshape(-1,)

# combine predicted property type dataframe with the non_nan property type dataframe
df2_pt_predict_done = pd.concat([df2_nan_pt_predict, df2_ml_not_nan_pt])

# update the dataframe that we've prepared to perform machine learning in the beginning so that we can use for the next prediction
df2_ml[df2_ml.columns[:-1]] = df2_pt_predict_done.reindex(df2_ml.index) # use reindex to match indices of df2_ml

# %%
df2_ml.isna().sum()
# Out:
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Years until sold         0
# Property Type            0
# Residential Type    367027
# dtype: int64

# %% [markdown]
# #### 2. Prediction for the residential type

# %%
df2_ml_rt = df2_ml[df2_ml['Property Type'] == 'Residential'].copy()

# %%
df2_ml_rt.head()
# Out:
#         Assessed Value  Sale Amount  Sales Ratio  Years until sold  \
# 816649         1000000    4150000.0      0.24096                 1
# 678302          100000      80830.0      1.23716                 1
# 719532            1000       4947.0      0.20214                 0
# 470663            1000       4000.0      0.25000                 1
# 681182           10000      41680.0      0.23992                 1
#
#        Property Type Residential Type
# 816649   Residential             <NA>
# 678302   Residential    Single Family
# 719532   Residential             <NA>
# 470663   Residential             <NA>
# 681182   Residential    Single Family

# %%
df2_ml_rt['Residential Type'].value_counts()
# Out:
# Residential Type
# Single Family    433885
# Condo            115658
# Two Family        28665
# Three Family      13596
# Four Family        2362
# Apartments          479
# Name: count, dtype: int64

# %%
df2_ml_non_nan_rt = df2_ml_rt[df2_ml_rt['Residential Type'].notna()].drop('Property Type', axis= 1).copy()
df2_ml_non_nan_rt
# Out:
#         Assessed Value  Sale Amount  Sales Ratio  Years until sold  \
# 678302          100000      80830.0      1.23716                 1
# 681182           10000      41680.0      0.23992                 1
# 748599            5000       3125.0      1.60000                 1
# 17155           500000     143995.0      3.47234                 1
# 721118           70000      60000.0      1.16667                 1
# ...                ...          ...          ...               ...
# 992641          385248     360730.0      1.06797                 1
# 994922          374769     418905.0      0.89464                 1
# 996063          222040     230450.0      0.96351                 1
# 996597          527692     482850.0      1.09287                 1
# 996735           90910      85000.0      1.06953                 1
#
#        Residential Type
# 678302    Single Family
# 681182    Single Family
# 748599    Single Family
# 17155     Single Family
# 721118            Condo
# ...                 ...
# 992641            Condo
# 994922            Condo
# 996063    Single Family
# 996597            Condo
# 996735    Single Family
#
# [594645 rows x 5 columns]

# %%
# pairplot for residential type
sns.pairplot(df2_ml_non_nan_rt, hue= 'Residential Type')
plt.show()

# %%
rt_train, rt_test = train_test_split(df2_ml_non_nan_rt, test_size= 0.6, random_state= 42, shuffle= True)

# %%
rt_train, rt_X_train, rt_y_train = scale_dataset(rt_train, 'Residential Type', oversample= True)
rt_test, rt_X_test, rt_y_test = scale_dataset(rt_test, 'Residential Type', oversample= False)

# %%
knn_residential = KNeighborsClassifier()

knn_residential.fit(rt_X_train, rt_y_train)
rt_y_pred = knn_residential.predict(rt_X_test)

# result
accuracy = accuracy_score(rt_y_test, rt_y_pred)
precision = precision_score(rt_y_test, rt_y_pred, average= 'weighted') 
recall = recall_score(rt_y_test, rt_y_pred, average= 'weighted')
f1 = f1_score(rt_y_test, rt_y_pred, average= 'weighted')

print('-'*35)
print(f'Accuracy = {accuracy}')
print(f'Precision Score = {precision}')
print(f'Recall Score = {recall}')
print(f'F1-score = {f1}')
print('-'*35)
# Out:
# -----------------------------------
# Accuracy = 0.5032890772365585
# Precision Score = 0.5888741499044178
# Recall Score = 0.5032890772365585
# F1-score = 0.5378981716125802
# -----------------------------------

# %%
models = {
    'Naive Bayes': GaussianNB(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier()
}

for i in range (len(list(models))):
    model = list(models.values())[i]

    model.fit(rt_X_train, rt_y_train)
    rt_y_pred = model.predict(rt_X_test)

    # result
    accuracy = accuracy_score(rt_y_test, rt_y_pred)
    precision = precision_score(rt_y_test, rt_y_pred, average= 'weighted') 
    recall = recall_score(rt_y_test, rt_y_pred, average= 'weighted')
    f1 = f1_score(rt_y_test, rt_y_pred, average= 'weighted')


    print('-'*35)
    print(list(models.keys())[i])
    print('-'*35)
    print(f'Accuracy = {accuracy}')
    print(f'Precision Score = {precision}')
    print(f'Recall Score = {recall}')
    print(f'F1-score = {f1}')
    print('-'*35)
    print()
# Out:
# -----------------------------------
# Naive Bayes
# -----------------------------------
# Accuracy = 0.03818244498818623
# Precision Score = 0.6801240073912689
# Recall Score = 0.03818244498818623
# F1-score = 0.03350121881180002
# -----------------------------------
#
# -----------------------------------
# Decision Tree
# -----------------------------------
# Accuracy = 0.4706365422506986
# Precision Score = 0.5859971373839178
# Recall Score = 0.4706365422506986
# F1-score = 0.5177782784391285
# -----------------------------------
#
# -----------------------------------
# Random Forest
# -----------------------------------
# Accuracy = 0.7256374251304
# Precision Score = 0.5802404884895657
# Recall Score = 0.7256374251304
# F1-score = 0.6176032175335553
# -----------------------------------

# %% [markdown]
# None of the machine learning models are performing well enough. Therfore, I need to do other approaches.

# %% [markdown]
# #### 2a. Replace some NaN values in the Residential Type column with residential type property in the same street

# %%
df2_ml = df2_ml[['Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type', 'Years until sold']]
df2_ml.head()
# Out:
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 58884             1000       3500.0      0.28571   Vacant Land
# 816649         1000000    4150000.0      0.24096   Residential
# 678302          100000      80830.0      1.23716   Residential
# 719532            1000       4947.0      0.20214   Residential
# 470663            1000       4000.0      0.25000   Residential
#
#        Residential Type  Years until sold
# 58884              <NA>                 1
# 816649             <NA>                 1
# 678302    Single Family                 1
# 719532             <NA>                 0
# 470663             <NA>                 1

# %%
# combine the df2_ml with df1_numeric done
df2_numeric_and_property_done =  df1_numeric_clean.copy()
df2_numeric_and_property_done.iloc[:, 5:] = df2_ml.reindex(df2_numeric_and_property_done.index)
df2_numeric_and_property_done.head()
# Out:
#         Serial Number  List Year Date Recorded       Town         Address  \
# 58884           20323       2020    2021-04-16  Waterford   ROBERTS COURT
# 816649         160511       2016    2017-03-31     Hamden    42 WARNER ST
# 678302         130111       2013    2014-09-04  Westbrook  5 PINE CONE DR
# 719532         140063       2014    2014-11-17  East Lyme        SO TRAIL
# 470663          70022       2007    2008-03-12     Sharon       ROUTE 343
#
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 58884             1000       3500.0      0.28571   Vacant Land
# 816649         1000000    4150000.0      0.24096   Residential
# 678302          100000      80830.0      1.23716   Residential
# 719532            1000       4947.0      0.20214   Residential
# 470663            1000       4000.0      0.25000   Residential
#
#        Residential Type  Years until sold
# 58884              <NA>                 1
# 816649             <NA>                 1
# 678302    Single Family                 1
# 719532             <NA>                 0
# 470663             <NA>                 1

# %%
# function to clean the address
def clean_address(address):
    words = address.split()  # split the address into words
    cleaned_words = []
    for word in words:
        cleaned_word = ''.join(e for e in word if e.isalpha())  # remove special characters and numbers
        if len(cleaned_word) >= 3:  # consider a word has minimum of 3 letters
            cleaned_words.append(cleaned_word)
    return (' '.join(cleaned_words)).lstrip()  # join the cleaned words back into a string

# %%
# Apply the function to create a new column
df2_numeric_and_property_done['Clean Address'] = df2_numeric_and_property_done['Address'].apply(lambda x: clean_address(x) if pd.notna(x) else x)
df2_numeric_and_property_done.head()
# Out:
#         Serial Number  List Year Date Recorded       Town         Address  \
# 58884           20323       2020    2021-04-16  Waterford   ROBERTS COURT
# 816649         160511       2016    2017-03-31     Hamden    42 WARNER ST
# 678302         130111       2013    2014-09-04  Westbrook  5 PINE CONE DR
# 719532         140063       2014    2014-11-17  East Lyme        SO TRAIL
# 470663          70022       2007    2008-03-12     Sharon       ROUTE 343
#
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 58884             1000       3500.0      0.28571   Vacant Land
# 816649         1000000    4150000.0      0.24096   Residential
# 678302          100000      80830.0      1.23716   Residential
# 719532            1000       4947.0      0.20214   Residential
# 470663            1000       4000.0      0.25000   Residential
#
#        Residential Type  Years until sold  Clean Address
# 58884              <NA>                 1  ROBERTS COURT
# 816649             <NA>                 1         WARNER
# 678302    Single Family                 1      PINE CONE
# 719532             <NA>                 0          TRAIL
# 470663             <NA>                 1          ROUTE

# %%
# select rows where 'Property Type' is 'Residential' and 'Residential Type' is not 'NaN'
filtered_df = df2_numeric_and_property_done[(df2_numeric_and_property_done['Property Type'] == 'Residential') & (df2_numeric_and_property_done['Residential Type'].notna())].sort_values(by=['Clean Address', 'Residential Type'])

# create new dataframe 
clean_address_residential = filtered_df[['Clean Address', 'Residential Type']]

# find the number of unique resident type value for each clean address
unique_addresses = clean_address_residential.groupby('Clean Address')['Residential Type'].nunique().reset_index()

# filter the grouped addresses to include only those with a single 'Residential Type'
single_residential_address = unique_addresses[unique_addresses['Residential Type'] == 1]['Clean Address'].values

# filter the unique addresses DataFrame to include only the clean addresses with a single 'Residential Type'
filtered_unique_addresses = clean_address_residential[clean_address_residential['Clean Address'].isin(single_residential_address)].drop_duplicates()

# convert the filtered unique addresses DataFrame to a dictionary
unique_addresses_dict = filtered_unique_addresses.set_index('Clean Address')['Residential Type'].to_dict()

# %%
unique_addresses_dict
# Out:
# {'AARON': 'Single Family',
#  'AARON SAMUELS BLVD': 'Two Family',
#  'AARONS': 'Single Family',
#  'AARONS WAY': 'Single Family',
#  'ABAR': 'Single Family',
#  'ABAR LANE': 'Single Family',
#  'ABBE EXT': 'Single Family',
#  'ABBE LANE': 'Single Family',
#  'ABBE ROAD': 'Single Family',
#  'ABBEWOOD': 'Condo',
#  'ABBEWOOD DRIVE': 'Condo',
#  'ABBEY ROAD': 'Single Family',
#  'ABBIE': 'Single Family',
#  'ABBOSTFORD AVE': 'Single Family',
#  'ABBOT': 'Condo',
#  'ABBOTS': 'Single Family',
#  'ABBOTSFORD': 'Condo',
#  'ABBOTSS HILL ROAD': 'Single Family',
#  'ABBOTT AVE': 'Single Family',
#  'ABBOTT AVENUE': 'Single Family',
#  'ABBOTT FARMS': 'Single Family',
#  'ABBOTT UNIT': 'Condo',
#  'ABBOTTS': 'Single Family',
#  'ABBOTTS HILL ROAD': 'Single Family',
#  'ABBOTTS LANE': 'Single Family',
#  'ABBOTTSFORD': 'Condo',
#  'ABBY': 'Single Family',
#  'ABBY LANE': 'Single Family',
#  'ABBY PARK': 'Condo',
#  'ABBY ROAD': 'Single Family',
#  'ABC FAIRFIELD BEACH': 'Condo',
#  'ABDG APT COURT': 'Single Family',
#  'ABEL XING': 'Condo',
#  'ABERDEEN COURT': 'Single Family',
#  'ABIGAIL': 'Single Family',
#  'ABIGAIL STREET': 'Single Family',
#  'ABINGTON': 'Single Family',
#  'ABINGTON EXT': 'Single Family',
#  'ABNER COURT': 'Condo',
#  'ABNER COURT COURT UNIT': 'Condo',
#  'ABNER COURT UNIT': 'Condo',
#  'ABORN': 'Single Family',
#  'ABORN PRIVATE': 'Single Family',
#  'ABOVE ALL': 'Single Family',
#  'ABRAHAM TER': 'Condo',
#  'ABRAM': 'Single Family',
#  'ABRAM NORTH': 'Single Family',
#  'ABRAM STN': 'Single Family',
#  'ABRAM STREET': 'Single Family',
#  'ABRAM STREET NORTH': 'Single Family',
#  'ABRAMS': 'Single Family',
#  'ABRAMS ROAD': 'Single Family',
#  'ABRERDEEM WAY': 'Condo',
#  'ABRIC': 'Single Family',
#  'ABRIC DRIVE': 'Single Family',
#  'ACACEA': 'Single Family',
#  'ACACIA': 'Single Family',
#  'ACADAMY': 'Two Family',
#  'ACADEMY HILL ROAD': 'Single Family',
#  'ACADEMY HILL TER': 'Single Family',
#  'ACADEMY HILL TERRACE': 'Single Family',
#  'ACADEMY ROAD': 'Single Family',
#  'ACADEMY STC': 'Condo',
#  'ACADEMY STREET UNIT': 'Condo',
#  'ACADEMY UNIT': 'Condo',
#  'ACADIA': 'Single Family',
#  'ACCESS': 'Single Family',
#  'ACCORNERO': 'Single Family',
#  'ACDADIA STREET': 'Single Family',
#  'ACER': 'Single Family',
#  'ACINTOSH LANE': 'Condo',
#  'ACKLEY CEMETARY': 'Single Family',
#  'ACKLEY CEMETERY': 'Single Family',
#  'ACME': 'Single Family',
#  'ACME DRIVE': 'Single Family',
#  'ACORN ALNE': 'Condo',
#  'ACORN AVE UNIT': 'Condo',
#  'ACORN AVENUE': 'Condo',
#  'ACORN DRIVE': 'Single Family',
#  'ACORN GLEN': 'Condo',
#  'ACORN HILL': 'Single Family',
#  'ACORN HILL ROAD': 'Single Family',
#  'ACORN HOLLOW': 'Condo',
#  'ACORN PLACE': 'Single Family',
#  'ACORN RIDGE': 'Single Family',
#  'ACORN ROAD': 'Single Family',
#  'ACORN WAY': 'Single Family',
#  'ACRA': 'Single Family',
#  'ACRE': 'Single Family',
#  'ACRE HYLO': 'Single Family',
#  'ACRE LANE': 'Single Family',
#  'ACRE VEIW DRIVE': 'Single Family',
#  'ACRE VIEW DRIVE': 'Single Family',
#  'ACRE WAY': 'Single Family',
#  'ACTION': 'Three Family',
#  'ACTON ROAD': 'Single Family',
#  'ACTON UNIT': 'Condo',
#  'ACUSHNET': 'Single Family',
#  'ACUSHNET STREET': 'Single Family',
#  'ADA': 'Single Family',
#  'ADA DRIVE': 'Single Family',
#  'ADAM HILL': 'Single Family',
#  'ADAM HTS': 'Single Family',
#  'ADAM LANE': 'Single Family',
#  'ADAM STREET': 'Single Family',
#  'ADAMEC': 'Single Family',
#  'ADAMO': 'Single Family',
#  'ADAMO AVE': 'Single Family',
#  'ADAMS AVENUE GARAGE': 'Condo',
#  'ADAMS AVENUE UNIT': 'Condo',
#  'ADAMS DRIVE': 'Single Family',
#  'ADAMS EXT': 'Two Family',
#  'ADAMS FARM': 'Single Family',
#  'ADAMS FARM ROAD': 'Single Family',
#  'ADAMS HEIGHTS': 'Single Family',
#  'ADAMS HEIGHTS CIR': 'Single Family',
#  'ADAMS HGTS': 'Single Family',
#  'ADAMS HILL': 'Single Family',
#  'ADAMS HILL LANE': 'Single Family',
#  'ADAMS HILL WAY': 'Condo',
#  'ADAMS HTS': 'Single Family',
#  'ADAMS HTS CIR': 'Single Family',
#  'ADAMS LANE': 'Single Family',
#  'ADAMS ROAD': 'Single Family',
#  'ADAMS SOUTH': 'Single Family',
#  'ADAMS STREET UNIT': 'Condo',
#  'ADAMSON AVE UNIT': 'Condo',
#  'ADANTI AVENUE': 'Single Family',
#  'ADDISION': 'Single Family',
#  'ADDISON POND': 'Condo',
#  'ADELAIDE AVE': 'Single Family',
#  'ADELAIDE ROAD': 'Single Family',
#  'ADELAIDE TER': 'Single Family',
#  'ADELBERT': 'Two Family',
#  'ADELE': 'Single Family',
#  'ADELINE AVE': 'Single Family',
#  'ADELINE PLACE': 'Single Family',
#  'ADELLA': 'Single Family',
#  'ADELLA STREET': 'Single Family',
#  'ADELMA': 'Single Family',
#  'ADEMA WAY': 'Single Family',
#  'ADEN CIR': 'Single Family',
#  'ADENAS WALK': 'Condo',
#  'ADIOS': 'Single Family',
#  'ADIRONDACK': 'Single Family',
#  'ADIRONDACK TRAIL': 'Single Family',
#  'ADLA': 'Single Family',
#  'ADLA DRIVE': 'Single Family',
#  'ADLAIDE': 'Three Family',
#  'ADLELAIDE': 'Two Family',
#  'ADLER': 'Two Family',
#  'ADLER COURT': 'Condo',
#  'ADLERWOOD DRIVE': 'Single Family',
#  'ADLEY': 'Single Family',
#  'ADLEY ROAD': 'Single Family',
#  'ADMIRAL COURT': 'Single Family',
#  'ADMIRAL DRIVE': 'Single Family',
#  'ADMIRAL STREET': 'Two Family',
#  'ADMIRMAL': 'Condo',
#  'ADMORE AVE': 'Single Family',
#  'ADOLF': 'Single Family',
#  'ADOO AVE': 'Single Family',
#  'ADORNO': 'Single Family',
#  'ADORNO DRIVE': 'Single Family',
#  'ADRIAN AVE': 'Single Family',
#  'ADRIAN AVENUE': 'Single Family',
#  'ADRIATIC': 'Single Family',
#  'ADVENT HILL': 'Single Family',
#  'ADVOCATE': 'Single Family',
#  'AETNA AVE': 'Single Family',
#  'AETNA LANE': 'Single Family',
#  'AETNA PLACE': 'Two Family',
#  'AETNA UNIT': 'Condo',
#  'AFFELDT': 'Single Family',
#  'AFFLECK': 'Three Family',
#  'AFTON TER': 'Single Family',
#  'AFTON TERR': 'Single Family',
#  'AGAUAM DRIVE': 'Single Family',
#  'AGAWAM AVE': 'Single Family',
#  'AGAWAM DRIVE': 'Condo',
#  'AGEROLA': 'Single Family',
#  'AGNES': 'Single Family',
#  'AGNES DRIVE': 'Single Family',
#  'AGONQUIN': 'Single Family',
#  'AGRESTA TERR': 'Single Family',
#  'AGRONOMY': 'Single Family',
#  'AGUE SPG': 'Single Family',
#  'AGUE SPRING': 'Single Family',
#  'AGUE SPRING ROAD': 'Single Family',
#  'AHARBOUR VILLAGE': 'Condo',
#  'AHERN': 'Single Family',
#  'AHERN AVE': 'Single Family',
#  'AHERN AVENUE': 'Single Family',
#  'AHERN DRIVE': 'Single Family',
#  'AIKEN AVE': 'Single Family',
#  'AIKEN GAR UNIT': 'Condo',
#  'AIKEN GARAGE': 'Condo',
#  'AIKEN ROAD': 'Single Family',
#  'AILEEN': 'Single Family',
#  'AIME': 'Single Family',
#  'AIMEE': 'Single Family',
#  'AIRCRAFT': 'Single Family',
#  'AIRLINE': 'Single Family',
#  'AIRLINE ROAD': 'Single Family',
#  'AIRPORT': 'Single Family',
#  'AIRWAY': 'Single Family',
#  'AISTIN': 'Two Family',
#  'AITCHISON': 'Single Family',
#  'AITCHISON DRIVE': 'Single Family',
#  'AJA': 'Single Family',
#  'AJELLOS FARM': 'Single Family',
#  'AKA GLEN RIDGE ROAD': 'Single Family',
#  'AKA GOODYEAR': 'Single Family',
#  'AKA MICHAEL': 'Single Family',
#  'AKA SAILORS LANE': 'Single Family',
#  'AKA WOLCOTT': 'Single Family',
#  'AKBAR ROAD': 'Single Family',
#  'AKE AVE': 'Condo',
#  'ALADDIN AVE': 'Single Family',
#  'ALAIMO': 'Single Family',
#  'ALAIN WHITE': 'Single Family',
#  'ALAMEDA': 'Single Family',
#  'ALAMEDA PLACE': 'Single Family',
#  'ALAN': 'Single Family',
#  'ALAN AVE': 'Single Family',
#  'ALAN DRIVE': 'Single Family',
#  'ALAN LANE': 'Single Family',
#  'ALANA DRIVE': 'Condo',
#  'ALANSON ROAD': 'Single Family',
#  'ALASKA': 'Single Family',
#  'ALBA': 'Single Family',
#  'ALBA AVE': 'Single Family',
#  'ALBACORE': 'Single Family',
#  'ALBAN': 'Single Family',
#  'ALBANY AVENUE': 'Single Family',
#  'ALBATROSS': 'Single Family',
#  'ALBATROSS DRIVE': 'Single Family',
#  'ALBEMARLE': 'Single Family',
#  'ALBEMARLE STREET': 'Single Family',
#  'ALBERMARLE': 'Single Family',
#  'ALBERS': 'Single Family',
#  'ALBERT AVENUE': 'Single Family',
#  'ALBERT ROAD': 'Single Family',
#  'ALBERT STREET': 'Single Family',
#  'ALBERTA': 'Single Family',
#  'ALBERTA ROAD': 'Single Family',
#  'ALBERTA STREET': 'Single Family',
#  'ALBERTS': 'Single Family',
#  'ALBERTS HILL ROAD': 'Single Family',
#  'ALBERTSON': 'Single Family',
#  'ALBERTSON WAY': 'Condo',
#  'ALBIN ROAD': 'Single Family',
#  'ALBION AVE': 'Single Family',
#  'ALBION STREET': 'Single Family',
#  'ALBOUGH': 'Single Family',
#  'ALBRECHT': 'Single Family',
#  'ALBRECHT ROAD': 'Single Family',
#  'ALBRIGHT': 'Single Family',
#  'ALBRIGHT AVE': 'Single Family',
#  'ALBRIGHT AVENUE': 'Single Family',
#  'ALBRIGHT LANE': 'Single Family',
#  'ALCIMA DRIVE': 'Single Family',
#  'ALCOTT': 'Single Family',
#  'ALCOTT STREET': 'Single Family',
#  'ALCOX': 'Single Family',
#  'ALDBOURNE': 'Single Family',
#  'ALDBOURNE DRIVE': 'Single Family',
#  'ALDEN AVENUE UNIT': 'Condo',
#  'ALDEN CIRCLE': 'Single Family',
#  'ALDEN COURT': 'Single Family',
#  'ALDEN LANE GRWCT': 'Single Family',
#  'ALDEN PLACE': 'Single Family',
#  'ALDEN QAVE': 'Single Family',
#  'ALDEN ROAD': 'Single Family',
#  'ALDEN STREET UNIT': 'Condo',
#  'ALDEN UNIT': 'Condo',
#  'ALDEN UNITS': 'Condo',
#  'ALDENS CROSSING': 'Single Family',
#  'ALDER COURT': 'Condo',
#  'ALDER COURT UNIT': 'Condo',
#  'ALDER ROAD': 'Single Family',
#  'ALDERLANE': 'Single Family',
#  'ALDERMAN LANE': 'Single Family',
#  'ALDERS BRIDGE': 'Single Family',
#  'ALDERS BRIDGE ROAD': 'Single Family',
#  'ALDERSON AVE': 'Single Family',
#  'ALDERWOOD': 'Single Family',
#  'ALDERWOOD DRIVE': 'Single Family',
#  'ALDINE AVENUE': 'Single Family',
#  'ALDINE PLACE': 'Single Family',
#  'ALDO': 'Single Family',
#  'ALDO DRIVE': 'Single Family',
#  'ALDON': 'Single Family',
#  'ALDON LANE': 'Single Family',
#  'ALDORISIO': 'Single Family',
#  'ALDRED CIR': 'Single Family',
#  'ALDRICH': 'Single Family',
#  'ALDRICH ROAD': 'Single Family',
#  'ALEC TEMPLETON LANE': 'Single Family',
#  'ALEC TEMPLETON LANEGRWCT': 'Single Family',
#  'ALEINER': 'Single Family',
#  'ALENIER': 'Single Family',
#  'ALEWIFE LANE': 'Single Family',
#  'ALEWIFE PARKWAY': 'Single Family',
#  'ALEWIFE ROAD': 'Single Family',
#  'ALEWIVES': 'Single Family',
#  'ALEX COURT': 'Single Family',
#  'ALEX DRIVE': 'Single Family',
#  'ALEX WARFIELD': 'Single Family',
#  'ALEXANDER GREENWICHCT': 'Single Family',
#  'ALEXANDER LANE': 'Single Family',
#  'ALEXANDER ROAD': 'Single Family',
#  'ALEXANDER STGRWCT': 'Two Family',
#  'ALEXANDER STREETGREENWICH': 'Two Family',
#  'ALEXANDER WAY': 'Single Family',
#  'ALEXANDRA': 'Single Family',
#  'ALEXANDRA DRIVE': 'Single Family',
#  'ALEXIS': 'Single Family',
#  'ALFORD': 'Single Family',
#  'ALFORD CIRCLE': 'Single Family',
#  'ALFRED CIR': 'Single Family',
#  'ALFRED CIRCLE': 'Single Family',
#  'ALFRED DRIVE': 'Single Family',
#  'ALFRED LANE': 'Single Family',
#  'ALFRED ROAD': 'Single Family',
#  'ALFREDSON': 'Single Family',
#  'ALFREDSON LANE': 'Single Family',
#  'ALGANET ROAD': 'Single Family',
#  'ALGER PLACE': 'Single Family',
#  'ALGIN': 'Single Family',
#  'ALGIN DRIVE': 'Single Family',
#  'ALGINQUIN ROAD': 'Single Family',
#  'ALGONKIN': 'Single Family',
#  'ALGONKIN ROAD': 'Single Family',
#  'ALGONQUIN AVENUE': 'Single Family',
#  'ALGONQUIN DRIVE': 'Single Family',
#  'ALGONQUIN ROAD': 'Single Family',
#  'ALGONQUIN UNIT': 'Condo',
#  'ALGONQUIN WAY': 'Single Family',
#  'ALICE ALICE STREE': 'Three Family',
#  'ALICE DRIVE': 'Single Family',
#  'ALICE EXT': 'Single Family',
#  'ALICE LANE': 'Single Family',
#  'ALICE PLACE': 'Single Family',
#  'ALICE TER': 'Single Family',
#  'ALICE UNIT': 'Condo',
#  'ALICIA': 'Single Family',
#  'ALICIA TER': 'Single Family',
#  'ALICIA TERR': 'Single Family',
#  'ALICIA TERRACE': 'Single Family',
#  'ALISHA': 'Single Family',
#  'ALISHA LANE': 'Single Family',
#  'ALISON AVE': 'Single Family',
#  'ALIX': 'Single Family',
#  'ALJEN AVE': 'Single Family',
#  'ALL HALLOWS': 'Single Family',
#  'ALLADDIN AVE': 'Single Family',
#  'ALLAN DRIVE': 'Single Family',
#  'ALLAN WAY': 'Single Family',
#  'ALLANE LANE': 'Single Family',
#  'ALLEN AVE EXT': 'Single Family',
#  'ALLEN AVENUE': 'Single Family',
#  'ALLEN DRIVE': 'Single Family',
#  'ALLEN FLORENCE': 'Single Family',
#  'ALLEN GROTON': 'Single Family',
#  'ALLEN HILL': 'Single Family',
#  'ALLEN HILL ROAD': 'Single Family',
#  'ALLEN LANE': 'Single Family',
#  'ALLEN PLACE': 'Single Family',
#  'ALLEN RIDGE': 'Single Family',
#  'ALLEN ROAD': 'Single Family',
#  'ALLEN STL': 'Single Family',
#  'ALLEN UNIT': 'Condo',
#  'ALLEN VERNON': 'Three Family',
#  'ALLENBY': 'Single Family',
#  'ALLENBY COURT': 'Single Family',
#  'ALLENCREST': 'Single Family',
#  'ALLENCREST DRIVE': 'Single Family',
#  'ALLENDALE DRIVE': 'Single Family',
#  'ALLENDALLE': 'Single Family',
#  'ALLENE': 'Single Family',
#  'ALLENTOWN ROAD': 'Single Family',
#  'ALLENTOWN UNIT': 'Condo',
#  'ALLERTON': 'Single Family',
#  'ALLERTON FARM': 'Single Family',
#  'ALLIKAT WAY': 'Single Family',
#  'ALLING AVE': 'Single Family',
#  'ALLING AVENUE': 'Single Family',
#  'ALLING EAST': 'Single Family',
#  'ALLING FARM': 'Single Family',
#  'ALLING STREET': 'Single Family',
#  'ALLINGS CROSSING': 'Single Family',
#  'ALLISON DRIVE': 'Single Family',
#  'ALLISONS WAY': 'Single Family',
#  'ALLISTER AVE': 'Single Family',
#  'ALLNTOWN': 'Single Family',
#  'ALLSPICE': 'Condo',
#  'ALLSTON': 'Single Family',
#  'ALLSTON ROAD': 'Single Family',
#  'ALLVIEW': 'Two Family',
#  'ALLWOOD': 'Single Family',
#  'ALLWOOD ROAD': 'Single Family',
#  'ALLYN AVE': 'Single Family',
#  'ALLYN ROAD': 'Single Family',
#  'ALLYN UNIT': 'Condo',
#  'ALLYNDALE': 'Single Family',
#  'ALLYNDALE COURT': 'Single Family',
#  'ALLYNDALE DRIVE': 'Single Family',
#  'ALLYNDALLE CIR': 'Single Family',
#  'ALLYNS ALLEY': 'Single Family',
#  'ALM': 'Single Family',
#  'ALMA AVE': 'Single Family',
#  'ALMA DRIVE': 'Single Family',
#  'ALMA ROCK ROAD': 'Single Family',
#  'ALMA STREET': 'Single Family',
#  'ALMADA': 'Single Family',
#  'ALMAR DRIVE': 'Single Family',
#  'ALMARGO': 'Single Family',
#  'ALMARGO AVE': 'Single Family',
#  'ALMARGO AVENUE': 'Single Family',
#  'ALMEDA DRIVE': 'Single Family',
#  'ALMER': 'Single Family',
#  'ALMIRA': 'Single Family',
#  'ALMIRA DRGRWCT': 'Condo',
#  'ALMIRA DRIVEGREENWICHCT': 'Condo',
#  'ALMIRA DRIVEGRWCT': 'Single Family',
#  'ALMIRA UNIT': 'Condo',
#  'ALMIRE DRIVEGREENWICHCT': 'Single Family',
#  'ALMOND': 'Single Family',
#  'ALOHA': 'Single Family',
#  'ALOHA LANE': 'Single Family',
#  'ALPERT': 'Single Family',
#  'ALPHA': 'Single Family',
#  'ALPHA AVE': 'Single Family',
#  'ALPHA AVENUE': 'Two Family',
#  'ALPHA STREET': 'Single Family',
#  'ALPINE AVE': 'Single Family',
#  'ALPINE CIR': 'Single Family',
#  'ALPINE CIRCLE': 'Single Family',
#  'ALPINE LANE': 'Single Family',
#  'ALPINE MDW': 'Condo',
#  'ALPINE MEADOW': 'Condo',
#  'ALPINE MEADOW LANE': 'Condo',
#  'ALPINE ROAD': 'Single Family',
#  'ALPINE ROAD GREENWICHCT': 'Single Family',
#  'ALPINE ROAD GRWCT': 'Single Family',
#  'ALPINE ROADGRWCT': 'Single Family',
#  'ALPINE TRAIL': 'Single Family',
#  'ALPINE TRL': 'Single Family',
#  'ALPINE UNIT': 'Condo',
#  'ALPOM': 'Single Family',
#  'ALPS': 'Single Family',
#  'ALPS DRIVE': 'Single Family',
#  'ALROWOOD': 'Single Family',
#  'ALSACE TERR': 'Single Family',
#  'ALSCOT DRIVE': 'Single Family',
#  'ALSCOT EAST': 'Single Family',
#  'ALSCOTT': 'Single Family',
#  'ALSON': 'Single Family',
#  'ALSTON': 'Single Family',
#  'ALSTON AVE': 'Single Family',
#  'ALSTON AVENUE': 'Single Family',
#  'ALSTON STREET': 'Single Family',
#  'ALSTRUM STREET': 'Single Family',
#  'ALTA VISTA AVE': 'Single Family',
#  'ALTA VISTA AVENUE': 'Single Family',
#  'ALTAIR AVE': 'Single Family',
#  'ALTAIR AVENUE': 'Single Family',
#  'ALTHEA': 'Three Family',
#  'ALTHEA LANE': 'Single Family',
#  'ALTIERE': 'Single Family',
#  'ALTMAN': 'Single Family',
#  'ALTO': 'Single Family',
#  'ALTO ROAD': 'Single Family',
#  'ALTON PLACE': 'Single Family',
#  'ALTON SOUTH': 'Single Family',
#  'ALTON STREET SOUTH': 'Single Family',
#  'ALTYRE': 'Single Family',
#  'ALVARD': 'Single Family',
#  'ALVIN': 'Single Family',
#  'ALVINA': 'Single Family',
#  'ALVINA AVE': 'Single Family',
#  'ALVORD': 'Single Family',
#  'ALVORD PARK': 'Single Family',
#  'ALVORD STREET': 'Single Family',
#  'ALWOOD': 'Single Family',
#  'ALWYN': 'Single Family',
#  'ALWYN LANE': 'Single Family',
#  'ALWYN WAY': 'Single Family',
#  'ALYCE TER': 'Single Family',
#  'ALYCE TERR': 'Single Family',
#  'ALYCE TERRACE': 'Single Family',
#  'ALYSSA DRIVE': 'Condo',
#  'ALYSSA LANE': 'Two Family',
#  'AMADEO': 'Single Family',
#  'AMANDA': 'Single Family',
#  'AMANDA CIR': 'Single Family',
#  'AMANDA CIRCLE': 'Single Family',
#  'AMANDA DRIVE': 'Single Family',
#  'AMANDA LANE': 'Single Family',
#  'AMANDA WAY': 'Single Family',
#  'AMANTE DRIVE': 'Single Family',
#  'AMATO CIR': 'Single Family',
#  'AMATO CIRCLE': 'Single Family',
#  'AMATO DRIVE': 'Condo',
#  'AMBASSADOR': 'Condo',
#  'AMBASSADOR DRIVE UNIT': 'Condo',
#  'AMBER': 'Single Family',
#  'AMBER CIR': 'Single Family',
#  'AMBER DRIVE': 'Single Family',
#  'AMBER LANE': 'Single Family',
#  'AMBER PLACE': 'Single Family',
#  'AMBER TRAIL': 'Single Family',
#  'AMBER TRL': 'Single Family',
#  'AMBERG': 'Single Family',
#  'AMBERG DRIVE': 'Single Family',
#  'AMBERLY LANE': 'Condo',
#  'AMBLER': 'Single Family',
#  'AMBLER DRIVE': 'Single Family',
#  'AMBLER ROAD': 'Single Family',
#  'AMBLER ROAD WEST': 'Single Family',
#  'AMBLESIDE': 'Condo',
#  'AMBROSE TER': 'Two Family',
#  'AMBROSE TERRACE': 'Two Family',
#  'AMELIA': 'Condo',
#  'AMELIA LANE': 'Condo',
#  'AMELIA PLACE': 'Single Family',
#  'AMENIA ROAD': 'Single Family',
#  'AMENIA UNION': 'Single Family',
#  'AMENIA UNIONM': 'Single Family',
#  'AMERICAN': 'Single Family',
#  'AMERIDE': 'Condo',
#  'AMERIDGE': 'Condo',
#  'AMERIDGE SALE': 'Condo',
#  'AMERIDGE UNIT': 'Condo',
#  'AMES': 'Single Family',
#  'AMES AVENUE': 'Single Family',
#  'AMES HOLLOW': 'Single Family',
#  'AMES HOLLOW ROAD': 'Single Family',
#  'AMES ROAD': 'Single Family',
#  'AMGEL PLACE': 'Single Family',
#  'AMHERST DRIVE': 'Single Family',
#  'AMHERST PLACE': 'Single Family',
#  'AMHERST ROAD': 'Single Family',
#  'AMHERST ROADRIVERSIDE': 'Single Family',
#  'AMIDON': 'Single Family',
#  'AMIDON AVE': 'Single Family',
#  'AMIDON AVENUE': 'Single Family',
#  'AMIE': 'Single Family',
#  'AMIE LANE': 'Single Family',
#  'AMITY HIGHLAND': 'Single Family',
#  'AMITY LOT': 'Single Family',
#  'AMITY ROAD': 'Single Family',
#  'AMITY STREET': 'Two Family',
#  'AMMJIM': 'Condo',
#  'AMNSFIELD GROVE UNIT': 'Condo',
#  'AMOLIA FARMS': 'Single Family',
#  'AMOS ROAD': 'Single Family',
#  'AMOS WHITE': 'Single Family',
#  'AMSHER': 'Single Family',
#  'AMSHERST': 'Single Family',
#  'AMSTERDAM AVE UNIT': 'Condo',
#  'AMTHONY ROAD': 'Single Family',
#  'AMUNDSEN': 'Single Family',
#  'AMY LANE': 'Single Family',
#  'AMYS': 'Single Family',
#  'AMYS LANE': 'Single Family',
#  'ANAWAN AVE': 'Single Family',
#  'ANAWAN AVENUE': 'Single Family',
#  'ANCHOR LANE': 'Single Family',
#  'ANCHOR REEF': 'Condo',
#  'ANCHOR REEF CLB': 'Condo',
#  'ANCHOR REEF CLUB': 'Condo',
#  'ANCHOR REEF CLUB UNIT': 'Condo',
#  'ANCHOR ROAD': 'Single Family',
#  'ANCHORAGE': 'Single Family',
#  'ANCHORAGE CIR': 'Single Family',
#  'ANCHORAGE CIRCLE': 'Single Family',
#  'ANCHORAGE DRIVE': 'Single Family',
#  'ANCHORAGE LANE': 'Single Family',
#  'ANCIENT HGWY': 'Single Family',
#  'ANCIENT HIGHWAY': 'Single Family',
#  'AND': 'Single Family',
#  'AND ARTHUR': 'Single Family',
#  'AND ASHLEY': 'Two Family',
#  'AND BEACH POND': 'Single Family',
#  'AND BEAVER STREET': 'Two Family',
#  'AND BISHOP ROAD': 'Single Family',
#  'AND BRADLEY': 'Four Family',
#  'AND BRAGG': 'Condo',
#  'AND BUSH HILL ROAD': 'Single Family',
#  'AND CHURCH STREET': 'Two Family',
#  'AND COOLEY': 'Single Family',
#  'AND COOPER': 'Apartments',
#  'AND DRIVEWAY': 'Single Family',
#  'AND DWIGHT': 'Condo',
#  'AND EVERGREEN': 'Condo',
#  'AND FIRST AVE': 'Two Family',
#  'AND HADDAM NECK': 'Single Family',
#  'AND HAVEN': 'Two Family',
#  'AND HEAD MEADOW ROAD': 'Single Family',
#  'AND JONES HILL': 'Single Family',
#  'AND KLONDIKE': 'Single Family',
#  'AND KNOLLS': 'Single Family',
#  'AND LAKEVIEW TERRACE': 'Single Family',
#  'AND LOT STANDISH ROAD': 'Single Family',
#  'AND MAIN': 'Two Family',
#  'AND MAIN STREET': 'Single Family',
#  'AND MARNE': 'Single Family',
#  'AND NORTH MAIN': 'Two Family',
#  'AND NORTH MAIN STREET': 'Condo',
#  'AND OLD QUARRY ROAD': 'Single Family',
#  'AND OLMSTED': 'Single Family',
#  'AND SOUTH': 'Three Family',
#  'AND SUNSET BEACH': 'Single Family',
#  'AND TAMARACK LANE': 'Single Family',
#  'AND THORME': 'Single Family',
#  'AND TOPHET': 'Single Family',
#  'AND TUNXIS ROAD': 'Single Family',
#  'AND WALLINGFORD ROAD': 'Single Family',
#  'ANDERSEN': 'Single Family',
#  'ANDERSON ACRES': 'Single Family',
#  'ANDERSON AVENUE': 'Single Family',
#  'ANDERSON EAST': 'Single Family',
#  'ANDERSON EXT': 'Single Family',
#  'ANDERSON GRWCT': 'Single Family',
#  'ANDERSON LANE': 'Single Family',
#  'ANDERSON ROAD': 'Single Family',
#  'ANDERSON ROAD GREENWICHCT': 'Single Family',
#  'ANDERSON ROADGREENWICH': 'Single Family',
#  'ANDERSON WAY': 'Single Family',
#  'ANDMAR': 'Single Family',
#  'ANDMAR LANE': 'Single Family',
#  'ANDON': 'Single Family',
#  'ANDOR': 'Single Family',
#  'ANDOR ROAD': 'Single Family',
#  'ANDOVER COURT': 'Condo',
#  'ANDOVER DRIVE': 'Single Family',
#  'ANDOVER ROAD': 'Single Family',
#  'ANDRAS ROAD': 'Single Family',
#  'ANDRASKO': 'Single Family',
#  'ANDRASKO ROAD': 'Single Family',
#  'ANDRASSY AVENUE UNIT': 'Condo',
#  'ANDRE': 'Single Family',
#  'ANDREA': 'Single Family',
#  'ANDREA AVE': 'Single Family',
#  'ANDREA COURT': 'Single Family',
#  'ANDREA DRIVE': 'Single Family',
#  'ANDREA LANE': 'Single Family',
#  'ANDREIS TRAIL': 'Single Family',
#  'ANDREIS TRL': 'Single Family',
#  'ANDREW': 'Single Family',
#  'ANDREW DRIVE': 'Single Family',
#  'ANDREW MNT': 'Single Family',
#  'ANDREW MOUNTAIN': 'Single Family',
#  'ANDREW MOUNTAIN ROAD': 'Single Family',
#  'ANDREW MOUNTAIND': 'Three Family',
#  'ANDREW MTN ROAD': 'Single Family',
#  'ANDREW PLACE': 'Single Family',
#  'ANDREW STREET': 'Single Family',
#  'ANDREW WAY': 'Single Family',
#  'ANDREWMOUNTAIN ROAD': 'Single Family',
#  'ANDREWS AVENUE': 'Single Family',
#  'ANDREWS CIRCLE': 'Condo',
#  'ANDREWS CLOSE': 'Condo',
#  'ANDREWS CLS': 'Condo',
#  'ANDREWS CLS UNIT': 'Condo',
#  'ANDREWS DRIVE': 'Single Family',
#  'ANDREWS DST': 'Single Family',
#  'ANDREWS FARM ROAD': 'Single Family',
#  'ANDREWS FARM ROAD GREENWIC': 'Single Family',
#  'ANDREWS ROAD': 'Single Family',
#  'ANDREWS UNA': 'Single Family',
#  'ANDRUS': 'Single Family',
#  'ANDRUS DRIVE': 'Single Family',
#  'ANDY': 'Single Family',
#  'ANDY LANE': 'Single Family',
#  'ANDYS': 'Single Family',
#  'ANELLA': 'Single Family',
#  'ANER STREET': 'Three Family',
#  'ANGE': 'Condo',
#  'ANGEL TRACE': 'Single Family',
#  'ANGEL VISTA': 'Single Family',
#  'ANGELA DRIVE': 'Single Family',
#  'ANGELDR': 'Condo',
#  'ANGELI': 'Single Family',
#  'ANGELI COURT': 'Single Family',
#  'ANGELL AVE': 'Single Family',
#  'ANGELL AVENUE': 'Single Family',
#  'ANGELS WAY': 'Single Family',
#  'ANGELUS': 'Single Family',
#  'ANGEVINE': 'Single Family',
#  'ANGLERS BEND': 'Single Family',
#  'ANGORA': 'Single Family',
#  'ANGORA ROAD': 'Single Family',
#  'ANGUILLA BROOK': 'Single Family',
#  'ANGUS': 'Single Family',
#  'ANGUS LANE': 'Single Family',
#  'ANGUS LANE GREENWICH': 'Single Family',
#  'ANGUS LANE GREENWICHCT': 'Single Family',
#  'ANGUS LANEGRWCT': 'Single Family',
#  'ANGUS NORTH': 'Single Family',
#  'ANGUS ROAD NORTH': 'Single Family',
#  'ANISE': 'Single Family',
#  'ANITA': 'Single Family',
#  'ANITA AVE': 'Single Family',
#  'ANITA AVENUE': 'Single Family',
#  'ANITA DRIVE': 'Single Family',
#  'ANITA STREET': 'Single Family',
#  'ANITA TER': 'Single Family',
#  'ANITA WAY': 'Single Family',
#  'ANJA': 'Condo',
#  'ANJA DRIVE': 'Condo',
#  'ANJIM DRIVE': 'Single Family',
#  'ANN DRIVE': 'Single Family',
#  'ANN EXT': 'Single Family',
#  'ANN FARMS': 'Single Family',
#  'ANN LANE': 'Single Family',
#  'ANN MAR': 'Single Family',
#  'ANN MAR LANE': 'Single Family',
#  'ANN PLACE': 'Single Family',
#  'ANN ROAD': 'Single Family',
#  'ANN ROSE': 'Single Family',
#  'ANN TER': 'Single Family',
#  'ANN TERRACE': 'Single Family',
#  'ANN UNIT': 'Condo',
#  'ANN VIEW TERR': 'Single Family',
#  'ANN VIEW TERRACE': 'Single Family',
#  'ANNA': 'Single Family',
#  'ANNA AVE': 'Single Family',
#  'ANNA FARM EAST': 'Single Family',
#  'ANNA FARM WEST': 'Single Family',
#  'ANNA JAY': 'Single Family',
#  'ANNA MARIA': 'Single Family',
#  'ANNA STREET': 'Single Family',
#  'ANNA TERRACE': 'Single Family',
#  'ANNADELL': 'Single Family',
#  'ANNAWON AVE': 'Single Family',
#  'ANNE': 'Single Family',
#  'ANNE CIR': 'Condo',
#  'ANNE CIRCLE': 'Condo',
#  'ANNELISE': 'Single Family',
#  'ANNELISE AVE': 'Single Family',
#  'ANNELLO WAY': 'Single Family',
#  'ANNES': 'Single Family',
#  'ANNES COURT': 'Single Family',
#  'ANNETTE': 'Single Family',
#  'ANNJIM': 'Single Family',
#  'ANNJIM DRIV': 'Single Family',
#  'ANNJIM DRIVE': 'Single Family',
#  'ANNJIM DRIVE GREENWICH': 'Single Family',
#  'ANNS FARM ROAD': 'Single Family',
#  'ANSALDI': 'Single Family',
#  'ANSALDI ROAD': 'Single Family',
#  'ANSANTAWAE': 'Single Family',
#  'ANSANTAWAE ROAD': 'Single Family',
#  'ANSMOUR': 'Single Family',
#  'ANSONIA DRIVE': 'Single Family',
#  'ANSONIA ROAD': 'Single Family',
#  'ANSONIAL': 'Single Family',
#  'ANSTON STREET': 'Three Family',
#  'ANTELOPE': 'Condo',
#  'ANTELOPE TRAIL': 'Condo',
#  'ANTELOPE TRL': 'Condo',
#  'ANTHES AVENUE': 'Single Family',
#  'ANTHOL': 'Condo',
#  'ANTHONY AVE': 'Single Family',
#  'ANTHONY AVENUE': 'Single Family',
#  'ANTHONY COURT': 'Single Family',
#  'ANTHONY DRIVE': 'Single Family',
#  'ANTHONY LANE': 'Single Family',
#  'ANTHONY PLACE': 'Single Family',
#  'ANTHONY PLACE RIVERSIDE': 'Single Family',
#  'ANTHONY RIDGE ROAD': 'Single Family',
#  'ANTHONY ROAD': 'Single Family',
#  'ANTHONY ROAD SOUTH': 'Single Family',
#  'ANTHONY STREEET': 'Four Family',
#  'ANTHONY STREET UNIT': 'Condo',
#  'ANTHONY TER': 'Single Family',
#  'ANTHONY TERR': 'Single Family',
#  'ANTHONY UNIT': 'Condo',
#  'ANTHONY WAY': 'Single Family',
#  'ANTHONYS': 'Single Family',
#  'ANTHONYS WAY': 'Single Family',
#  'ANTHORNY': 'Two Family',
#  'ANTIOCH': 'Single Family',
#  'ANTIONETTE': 'Single Family',
#  'ANTIONIETTE': 'Single Family',
#  'ANTLER': 'Single Family',
#  'ANTLER LANE': 'Single Family',
#  'ANTLER PINE ROAD': 'Single Family',
#  'ANTLER PNE': 'Single Family',
#  'ANTOINETTE': 'Single Family',
#  'ANTOINETTE STREET': 'Single Family',
#  'ANTON AVENUE': 'Single Family',
#  'ANTON CIR': 'Single Family',
#  'ANTON DRIVE UNIT': 'Condo',
#  'ANTON LANE': 'Single Family',
#  'ANTON STREET': 'Single Family',
#  'ANTON UNIT': 'Condo',
#  'ANTRIM': 'Single Family',
#  'ANVIL': 'Single Family',
#  'ANVIL DRIVE': 'Single Family',
#  'ANVIL ROAD': 'Single Family',
#  'APACE': 'Single Family',
#  'APACHE DRIVE': 'Single Family',
#  'APACHE LANE': 'Condo',
#  'APACHE RIVERSIDE': 'Three Family',
#  'APACHE RUN': 'Single Family',
#  'APACHE TRAIL': 'Single Family',
#  'APACHE TRL': 'Single Family',
#  'APACHE UNIT': 'Condo',
#  'APLIN HILL': 'Single Family',
#  'APLLE GATE': 'Condo',
#  'APLLEGATE': 'Single Family',
#  'APOGEE LANE': 'Single Family',
#  'APOLLO ROAD': 'Single Family',
#  'APOLLOO ROAD': 'Single Family',
#  'APOTHACARIES HALL': 'Single Family',
#  'APOTHECARIES HALL': 'Single Family',
#  'APPALACHIAN': 'Single Family',
#  'APPELL': 'Single Family',
#  'APPIAN WAY': 'Single Family',
#  'APPLE BLOSSOM DRIVE': 'Single Family',
#  'APPLE BLOSSOM LANE': 'Single Family',
#  'APPLE CIDER RIDGE': 'Single Family',
#  'APPLE DRIVE': 'Single Family',
#  'APPLE HILL DRIVE': 'Single Family',
#  'APPLE HILL ROAD': 'Single Family',
#  'APPLE ORCHARD': 'Single Family',
#  'APPLE RIDGE': 'Single Family',
#  'APPLE TREE DRIVE': 'Single Family',
#  'APPLE TREE HILL': 'Single Family',
#  'APPLE TREE LANE': 'Single Family',
#  'APPLE TREE ROAD': 'Single Family',
#  'APPLE TREE TER': 'Single Family',
#  'APPLE TREE TERR': 'Single Family',
#  'APPLE TREE TRAIL': 'Single Family',
#  'APPLE TREE TRL': 'Single Family',
#  'APPLE UNIT': 'Condo',
#  'APPLE VALLE ROAD': 'Single Family',
#  'APPLE VALLEY ROAD': 'Single Family',
#  'APPLEBEE ROAD': 'Single Family',
#  'APPLEBLOSSOM': 'Single Family',
#  'APPLEBLOSSOM LANE': 'Single Family',
#  'APPLEBY FARM': 'Single Family',
#  'APPLEGATE LANE': 'Single Family',
#  'APPLEGATE ROAD': 'Single Family',
#  'APPLETON': 'Single Family',
#  'APPLETON AVE': 'Single Family',
#  'APPLETREE': 'Single Family',
#  'APPLETREE DRIVE': 'Single Family',
#  'APPLETREE LANE': 'Single Family',
#  'APPLETREE ROAD': 'Single Family',
#  'APPLETREE TER': 'Single Family',
#  'APPLETREE TRL': 'Single Family',
#  'APPLEWOOD COMMON': 'Single Family',
#  'APPLEWOOD CONDO': 'Condo',
#  'APPLEWOOD DRIVE': 'Single Family',
#  'APRICOT': 'Condo',
#  'APRICOT LANE': 'Single Family',
#  'APRIL': 'Single Family',
#  'APRIL DRIVE': 'Single Family',
#  'APRIL GARDENS ROAD UNIT': 'Condo',
#  'APRIL GARDENS UNIT': 'Condo',
#  'APRIL GDNS': 'Condo',
#  'APRIL LANE': 'Single Family',
#  'APRIL WAY': 'Single Family',
#  'APT BLDG GREENFIELD AVE': 'Single Family',
#  'APTER': 'Single Family',
#  'AQUATERRA': 'Single Family',
#  'AQUATIC': 'Single Family',
#  'AQUATIC LANE': 'Single Family',
#  'AQUATIC ROAD': 'Single Family',
#  'AQUILA ROAD': 'Single Family',
#  'ARAGON': 'Single Family',
#  'ARAGON DRIVE': 'Single Family',
#  'ARAMAN CIRCLE': 'Single Family',
#  'ARAMON CIR': 'Single Family',
#  'ARAMON CIRCLE': 'Single Family',
#  'ARAN': 'Single Family',
#  'ARAN HILL ROAD': 'Single Family',
#  'ARAPAHO DRIVE': 'Single Family',
#  'ARAPAHO LANE': 'Condo',
#  'ARAPAHOE ROAD': 'Single Family',
#  'ARAPHO': 'Single Family',
#  'ARAWAK DRIVE': 'Single Family',
#  'ARAWAK ROAD': 'Single Family',
#  'ARBOR AVE': 'Single Family',
#  'ARBOR COURT': 'Single Family',
#  'ARBOR CROSSING': 'Single Family',
#  'ARBOR LANE': 'Single Family',
#  'ARBOR MDW': 'Single Family',
#  'ARBOR MEADOW': 'Single Family',
#  'ARBOR MEADOW DRIVE': 'Single Family',
#  'ARBOR RIDGE': 'Single Family',
#  'ARBOR ROAD': 'Single Family',
#  'ARBOR STREET': 'Single Family',
#  'ARBOR TER': 'Single Family',
#  'ARBOR TERR': 'Single Family',
#  'ARBOR TERRACE': 'Single Family',
#  'ARBUTUS': 'Single Family',
#  'ARBUTUS BEND': 'Single Family',
#  'ARBUTUS LANE': 'Single Family',
#  'ARBUTUS STREET': 'Single Family',
#  'ARBUTUS VEND': 'Single Family',
#  'ARCADIA': 'Single Family',
#  'ARCADIA AVENUE': 'Single Family',
#  'ARCADIA CIR': 'Single Family',
#  'ARCADIA ROAD': 'Single Family',
#  'ARCADIA ROAD OGCT': 'Single Family',
#  'ARCADIAN': 'Single Family',
#  'ARCELLA DRIVE': 'Single Family',
#  'ARCELLIA': 'Single Family',
#  'ARCELLIA DRIVE': 'Single Family',
#  'ARCH BRIDGE': 'Single Family',
#  'ARCH LOCUST': 'Four Family',
#  'ARCH ROAD': 'Single Family',
#  'ARCH RVSD': 'Single Family',
#  'ARCH UNIT': 'Condo',
#  'ARCHBRIDGE': 'Single Family',
#  'ARCHER LANE': 'Single Family',
#  'ARCHERS': 'Single Family',
#  'ARCHERS LANE': 'Single Family',
#  'ARCHIE': 'Single Family',
#  'ARCSH': 'Three Family',
#  'ARCTIC BEACH': 'Two Family',
#  'ARD': 'Single Family',
#  'ARD COURT': 'Single Family',
#  'ARDELL': 'Single Family',
#  'ARDEN': 'Single Family',
#  'ARDEN AVE': 'Single Family',
#  'ARDEN LANE': 'Single Family',
#  'ARDEN PLACE': 'Single Family',
#  'ARDEN ROAD': 'Single Family',
#  'ARDEN STREET': 'Single Family',
#  'ARDI COURT': 'Condo',
#  'ARDSLEY ROAD': 'Single Family',
#  'ARDSLEY WAY': 'Single Family',
#  'ARESCO': 'Single Family',
#  'ARGANESE': 'Condo',
#  'ARGANESE PLACE': 'Condo',
#  'ARGANESE PLACE UNIT': 'Condo',
#  'ARGANESE PLUNIT': 'Condo',
#  'ARGANESE UNIT': 'Condo',
#  'ARGENTINE WAY': 'Single Family',
#  'ARGLYLE': 'Single Family',
#  'ARGONNE': 'Single Family',
#  'ARGONNE DRIVE': 'Single Family',
#  'ARGONNE STREET': 'Single Family',
#  'ARGONNE TERR': 'Single Family',
#  'ARGUS LANE': 'Single Family',
#  'ARGYLE': 'Single Family',
#  'ARGYLE AVE': 'Single Family',
#  'ARGYLE CIR': 'Single Family',
#  'ARGYLE CIRCLE': 'Single Family',
#  'ARGYLE ROAD': 'Single Family',
#  'ARIEL WAY': 'Single Family',
#  'ARK': 'Single Family',
#  'ARK ENTRY': 'Single Family',
#  'ARK ROAD': 'Single Family',
#  'ARKAY': 'Single Family',
#  'ARKAY DRIVE': 'Single Family',
#  'ARKONA': 'Single Family',
#  'ARKONA LANE': 'Single Family',
#  'ARLEN': 'Single Family',
#  'ARLEN ROAD': 'Single Family',
#  'ARLEN WAY': 'Single Family',
#  'ARLENE': 'Single Family',
#  'ARLENE COURT': 'Single Family',
#  'ARLI': 'Single Family',
#  'ARLI COURT': 'Single Family',
#  'ARLINE': 'Single Family',
#  'ARLINGTON AVE': 'Single Family',
#  'ARLINGTON HGTS': 'Single Family',
#  'ARLINGTON LOT ARLI': 'Single Family',
#  'ARLISS DRIVE': 'Single Family',
#  'ARLMONT': 'Single Family',
#  'ARLMONT STREET': 'Single Family',
#  'ARLYN RIDGE ROAD': 'Single Family',
#  'ARMAND ESTATES': 'Condo',
#  'ARMAND ROAD': 'Single Family',
#  'ARMBRUSTER': 'Single Family',
#  'ARMBRUSTER ROAD': 'Single Family',
#  'ARMITAGE': 'Single Family',
#  'ARMONK STREET': 'Two Family',
#  'ARMORY': 'Single Family',
#  'ARMORY STREET': 'Single Family',
#  'ARMSTRING': 'Condo',
#  'ARMSTRONG COURT': 'Single Family',
#  'ARMSTRONG LANE': 'Single Family',
#  'ARMSTRONG ROAD UNIT': 'Condo',
#  'ARMSTRONG UNIT': 'Condo',
#  'ARNIO': 'Single Family',
#  'ARNOLD AVE': 'Single Family',
#  'ARNOLD DRIVE': 'Single Family',
#  'ARNOLD LANE': 'Single Family',
#  'ARNOLD PLACE': 'Single Family',
#  'ARNOLD RIDGE': 'Condo',
#  'ARNOLD RIVCT': 'Single Family',
#  ...}

# %%
df2_numeric_and_property_done['Residential Type'] = df2_numeric_and_property_done.apply(lambda x: x['Residential Type'] 
                                                                                             if x['Property Type'] != 'Residential' 
                                                                                             else (x['Residential Type']
                                                                                                   if pd.notna(x['Residential Type'])
                                                                                                   else unique_addresses_dict.get(x['Clean Address'], np.nan)), 
                                                                                             axis=1)

# %%
df2_numeric_and_property_done[(df2_numeric_and_property_done['Property Type']!='Residential')
                              & (df2_numeric_and_property_done['Residential Type'].notna())]
# Out:
# Empty DataFrame
# Columns: [Serial Number, List Year, Date Recorded, Town, Address, Assessed Value, Sale Amount, Sales Ratio, Property Type, Residential Type, Years until sold, Clean Address]
# Index: []

# %%
df2_numeric_and_property_done.isna().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            0
# Town                     0
# Address                 30
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type            0
# Residential Type    278409
# Years until sold         0
# Clean Address           30
# dtype: int64

# %% [markdown]
# #### 2b. Label encoded Town feature

# %%
label_encoder = LabelEncoder()

# %%
df2_label_encoder = df2_numeric_and_property_done.copy()

# %%
df2_label_encoder['Town Encoded'] = label_encoder.fit_transform(df2_label_encoder['Town'])

# %%
df2_label_encoder.head()
# Out:
#         Serial Number  List Year Date Recorded       Town         Address  \
# 58884           20323       2020    2021-04-16  Waterford   ROBERTS COURT
# 816649         160511       2016    2017-03-31     Hamden    42 WARNER ST
# 678302         130111       2013    2014-09-04  Westbrook  5 PINE CONE DR
# 719532         140063       2014    2014-11-17  East Lyme        SO TRAIL
# 470663          70022       2007    2008-03-12     Sharon       ROUTE 343
#
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 58884             1000       3500.0      0.28571   Vacant Land
# 816649         1000000    4150000.0      0.24096   Residential
# 678302          100000      80830.0      1.23716   Residential
# 719532            1000       4947.0      0.20214   Residential
# 470663            1000       4000.0      0.25000   Residential
#
#        Residential Type  Years until sold  Clean Address  Town Encoded
# 58884              <NA>                 1  ROBERTS COURT           152
# 816649              NaN                 1         WARNER            62
# 678302    Single Family                 1      PINE CONE           156
# 719532              NaN                 0          TRAIL            44
# 470663              NaN                 1          ROUTE           125

# %%
df2_ml_rt_le = df2_label_encoder[['Town Encoded','Years until sold', 'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type']]
df2_ml_rt_le.describe()
# Out:
#         Town Encoded  Years until sold  Assessed Value   Sale Amount  \
# count  961672.000000     961672.000000    9.616720e+05  9.616720e+05
# mean       89.210533          0.748671    3.220757e+05  4.461258e+05
# std        47.424723          0.433833    3.385001e+06  5.664292e+06
# min         0.000000          0.000000    0.000000e+00  0.000000e+00
# 25%        51.000000          0.000000    9.319000e+04  1.450000e+05
# 50%        89.000000          1.000000    1.444800e+05  2.300000e+05
# 75%       135.000000          1.000000    2.374000e+05  3.700000e+05
# max       169.000000          4.000000    2.238530e+09  5.000000e+09
#
#          Sales Ratio
# count  961672.000000
# mean        0.762525
# std         0.579659
# min         0.200000
# 25%         0.504180
# 50%         0.636790
# 75%         0.803072
# max         8.000000

# %%
df2_ml_non_nan_rt_le = df2_ml_rt_le[(df2_ml_rt_le['Residential Type'].notna())
                               & (df2_ml_rt_le['Property Type']=='Residential')].drop('Property Type', axis= 1).copy()
df2_ml_non_nan_rt_le
# Out:
#         Town Encoded  Years until sold  Assessed Value  Sale Amount  \
# 678302           156                 1          100000      80830.0
# 681182           156                 1           10000      41680.0
# 712586            44                 0            1000       4617.0
# 379808            52                 0          200000     369318.0
# 267595           101                 1          300000     425000.0
# ...              ...               ...             ...          ...
# 307257            85                 1          463840     580000.0
# 320979           162                 1           40314      97000.0
# 323184           103                 0          283220     520000.0
# 344353           158                 0          124110     185000.0
# 874940            57                 1          171710     390000.0
#
#         Sales Ratio Residential Type
# 678302      1.23716    Single Family
# 681182      0.23992    Single Family
# 712586      0.21659    Single Family
# 379808      0.54154            Condo
# 267595      0.70588    Single Family
# ...             ...              ...
# 307257      0.79972    Single Family
# 320979      0.41561    Single Family
# 323184      0.54465            Condo
# 344353      0.67086    Single Family
# 874940      0.44028    Single Family
#
# [683263 rows x 6 columns]

# %%
rt_train, rt_test = train_test_split(df2_ml_non_nan_rt_le, test_size= 0.6, random_state= 42, shuffle= True)

# %%
rt_train, rt_X_train, rt_y_train = scale_dataset(rt_train, 'Residential Type', oversample= True)
rt_test, rt_X_test, rt_y_test = scale_dataset(rt_test, 'Residential Type', oversample= False)

# %%
random_forest = RandomForestClassifier()

random_forest.fit(rt_X_train, rt_y_train)
rt_y_pred = random_forest.predict(rt_X_test)

# result
accuracy = accuracy_score(rt_y_test, rt_y_pred)
precision = precision_score(rt_y_test, rt_y_pred, average= 'weighted') 
recall = recall_score(rt_y_test, rt_y_pred, average= 'weighted')
f1 = f1_score(rt_y_test, rt_y_pred, average= 'weighted')

print('-'*35)
print(f'Accuracy = {accuracy}')
print(f'Precision Score = {precision}')
print(f'Recall Score = {recall}')
print(f'F1-score = {f1}')
print('-'*35)
# Out:
# -----------------------------------
# Accuracy = 0.7487010864527586
# Precision Score = 0.6661131675501765
# Recall Score = 0.7487010864527586
# F1-score = 0.6669968745160764
# -----------------------------------

# %% [markdown]
# #### 2c. Apply One-Hot-Encoding for Top 10 towns

# %%
df2_ml_rt_ohe = df2_numeric_and_property_done[['Town','Years until sold', 'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type']]
df2_ml_rt_ohe.head()
# Out:
#              Town  Years until sold  Assessed Value  Sale Amount  Sales Ratio  \
# 58884   Waterford                 1            1000       3500.0      0.28571
# 816649     Hamden                 1         1000000    4150000.0      0.24096
# 678302  Westbrook                 1          100000      80830.0      1.23716
# 719532  East Lyme                 0            1000       4947.0      0.20214
# 470663     Sharon                 1            1000       4000.0      0.25000
#
#        Property Type Residential Type
# 58884    Vacant Land             <NA>
# 816649   Residential              NaN
# 678302   Residential    Single Family
# 719532   Residential              NaN
# 470663   Residential              NaN

# %%
top10_towns = np.array(df2_ml_rt_ohe[(df2_ml_rt_ohe['Property Type']=='Residential')
                              & (df2_ml_rt_ohe['Residential Type'].notna())]['Town'].value_counts().head(10).index)
top10_towns
# Out:
# array(['Stamford', 'Bridgeport', 'Waterbury', 'Norwalk', 'West Hartford',
#        'Danbury', 'Greenwich', 'Fairfield', 'Milford', 'New Haven'],
#       dtype=object)

# %%
for town in top10_towns:
    df2_ml_rt_ohe[town] = np.where(df2_ml_rt_ohe['Town'] == town, 1, 0)
# Out:
# C:\Users\fredl\AppData\Local\Temp\ipykernel_3256\736457868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ml_rt_ohe[town] = np.where(df2_ml_rt_ohe['Town'] == town, 1, 0)
# C:\Users\fredl\AppData\Local\Temp\ipykernel_3256\736457868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ml_rt_ohe[town] = np.where(df2_ml_rt_ohe['Town'] == town, 1, 0)
# C:\Users\fredl\AppData\Local\Temp\ipykernel_3256\736457868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ml_rt_ohe[town] = np.where(df2_ml_rt_ohe['Town'] == town, 1, 0)
# C:\Users\fredl\AppData\Local\Temp\ipykernel_3256\736457868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ml_rt_ohe[town] = np.where(df2_ml_rt_ohe['Town'] == town, 1, 0)

# %%
df2_ml_rt_ohe=df2_ml_rt_ohe[['Stamford', 'Bridgeport', 'Waterbury', 'Norwalk', 'West Hartford','Danbury', 'Greenwich', 'Fairfield', 'Milford', 'New Haven', 'Years until sold','Assessed Value','Sale Amount','Sales Ratio','Property Type','Residential Type']]

# %%
df2_ml_non_nan_rt_ohe = df2_ml_rt_ohe[(df2_ml_rt_ohe['Residential Type'].notna())
                                   & (df2_ml_rt_ohe['Property Type']=='Residential')].drop('Property Type', axis= 1).copy()
df2_ml_non_nan_rt_ohe.head()
# Out:
#         Stamford  Bridgeport  Waterbury  Norwalk  West Hartford  Danbury  \
# 678302         0           0          0        0              0        0
# 681182         0           0          0        0              0        0
# 712586         0           0          0        0              0        0
# 379808         0           0          0        0              0        0
# 267595         0           0          0        0              0        0
#
#         Greenwich  Fairfield  Milford  New Haven  Years until sold  \
# 678302          0          0        0          0                 1
# 681182          0          0        0          0                 1
# 712586          0          0        0          0                 0
# 379808          0          0        0          0                 0
# 267595          0          0        0          0                 1
#
#         Assessed Value  Sale Amount  Sales Ratio Residential Type
# 678302          100000      80830.0      1.23716    Single Family
# 681182           10000      41680.0      0.23992    Single Family
# 712586            1000       4617.0      0.21659    Single Family
# 379808          200000     369318.0      0.54154            Condo
# 267595          300000     425000.0      0.70588    Single Family

# %%
rt_train, rt_test = train_test_split(df2_ml_non_nan_rt_ohe, test_size= 0.6, random_state= 42, shuffle= True)

# %%
rt_train, rt_X_train, rt_y_train = scale_dataset(rt_train, 'Residential Type', oversample= True)
rt_test, rt_X_test, rt_y_test = scale_dataset(rt_test, 'Residential Type', oversample= False)

# %%
random_forest = RandomForestClassifier()

random_forest.fit(rt_X_train, rt_y_train)
rt_y_pred = random_forest.predict(rt_X_test)

# result
accuracy = accuracy_score(rt_y_test, rt_y_pred)
precision = precision_score(rt_y_test, rt_y_pred, average= 'weighted') 
recall = recall_score(rt_y_test, rt_y_pred, average= 'weighted')
f1 = f1_score(rt_y_test, rt_y_pred, average= 'weighted')

print('-'*35)
print(f'Accuracy = {accuracy}')
print(f'Precision Score = {precision}')
print(f'Recall Score = {recall}')
print(f'F1-score = {f1}')
print('-'*35)
# Out:
# -----------------------------------
# Accuracy = 0.7466496567941107
# Precision Score = 0.6719070708256835
# Recall Score = 0.7466496567941107
# F1-score = 0.6735761917503519
# -----------------------------------

# %% [markdown]
# #### 2d. Apply K-Fold Target Encoding for Town

# %%
from sklearn.preprocessing import TargetEncoder

# %%
df2_ml_rt_kte = df2_numeric_and_property_done[['Town','Years until sold', 'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type']]
df2_ml_rt_kte.head()
# Out:
#              Town  Years until sold  Assessed Value  Sale Amount  Sales Ratio  \
# 58884   Waterford                 1            1000       3500.0      0.28571
# 816649     Hamden                 1         1000000    4150000.0      0.24096
# 678302  Westbrook                 1          100000      80830.0      1.23716
# 719532  East Lyme                 0            1000       4947.0      0.20214
# 470663     Sharon                 1            1000       4000.0      0.25000
#
#        Property Type Residential Type
# 58884    Vacant Land             <NA>
# 816649   Residential              NaN
# 678302   Residential    Single Family
# 719532   Residential              NaN
# 470663   Residential              NaN

# %%
df2_ml_non_nan_rt_kte = df2_ml_rt_kte[df2_ml_rt_kte['Residential Type'].notna()]
df2_ml_non_nan_rt_kte.head()
# Out:
#                Town  Years until sold  Assessed Value  Sale Amount  \
# 678302    Westbrook                 1          100000      80830.0
# 681182    Westbrook                 1           10000      41680.0
# 712586    East Lyme                 0            1000       4617.0
# 379808   Farmington                 0          200000     369318.0
# 267595  North Haven                 1          300000     425000.0
#
#         Sales Ratio Property Type Residential Type
# 678302      1.23716   Residential    Single Family
# 681182      0.23992   Residential    Single Family
# 712586      0.21659   Residential    Single Family
# 379808      0.54154   Residential            Condo
# 267595      0.70588   Residential    Single Family

# %%
target_encoder = TargetEncoder(cv=5, random_state=42)

# %%
town_encode = target_encoder.fit(df2_ml_non_nan_rt_kte[['Town']],df2_ml_non_nan_rt_kte[['Residential Type']])

# %%
town_encode = target_encoder.transform(df2_ml_non_nan_rt_kte[['Town']])

# %%
town_encode
# Out:
# array([[0.00000000e+00, 7.16767396e-02, 1.03880090e-03, 9.08063222e-01,
#         2.07782789e-03, 1.71394256e-02],
#        [0.00000000e+00, 7.16767396e-02, 1.03880090e-03, 9.08063222e-01,
#         2.07782789e-03, 1.71394256e-02],
#        [0.00000000e+00, 2.21699477e-01, 4.19981191e-04, 7.65480916e-01,
#         4.19991475e-04, 1.19691142e-02],
#        ...,
#        [9.40543597e-04, 3.15074501e-01, 2.50819556e-03, 6.25417383e-01,
#         7.96368632e-03, 4.80934276e-02],
#        [0.00000000e+00, 5.78436156e-02, 0.00000000e+00, 9.34622697e-01,
#         9.94879064e-04, 6.53769301e-03],
#        [0.00000000e+00, 1.83918282e-01, 1.57522236e-03, 7.69125585e-01,
#         6.82602534e-03, 3.85541385e-02]])

# %%
df2_ml_non_nan_rt_kte.loc[:,'Town'] = town_encode[:, 0]

# %%
df2_ml_non_nan_rt_kte
# Out:
#             Town  Years until sold  Assessed Value  Sale Amount  Sales Ratio  \
# 678302       0.0                 1          100000      80830.0      1.23716
# 681182       0.0                 1           10000      41680.0      0.23992
# 712586       0.0                 0            1000       4617.0      0.21659
# 379808  0.000314                 0          200000     369318.0      0.54154
# 267595   0.00021                 1          300000     425000.0      0.70588
# ...          ...               ...             ...          ...          ...
# 307257       0.0                 1          463840     580000.0      0.79972
# 320979       0.0                 1           40314      97000.0      0.41561
# 323184  0.000941                 0          283220     520000.0      0.54465
# 344353       0.0                 0          124110     185000.0      0.67086
# 874940       0.0                 1          171710     390000.0      0.44028
#
#        Property Type Residential Type
# 678302   Residential    Single Family
# 681182   Residential    Single Family
# 712586   Residential    Single Family
# 379808   Residential            Condo
# 267595   Residential    Single Family
# ...              ...              ...
# 307257   Residential    Single Family
# 320979   Residential    Single Family
# 323184   Residential            Condo
# 344353   Residential    Single Family
# 874940   Residential    Single Family
#
# [683263 rows x 7 columns]

# %%
rt_train, rt_test = train_test_split(df2_ml_non_nan_rt_kte.drop('Property Type', axis=1), test_size= 0.6, random_state= 42, shuffle= True)

# %%
rt_train, rt_X_train, rt_y_train = scale_dataset(rt_train, 'Residential Type', oversample= True)
rt_test, rt_X_test, rt_y_test = scale_dataset(rt_test, 'Residential Type', oversample= False)

# %%
random_forest = RandomForestClassifier()

random_forest.fit(rt_X_train, rt_y_train)
rt_y_pred = random_forest.predict(rt_X_test)

# result
accuracy = accuracy_score(rt_y_test, rt_y_pred)
precision = precision_score(rt_y_test, rt_y_pred, average= 'weighted') 
recall = recall_score(rt_y_test, rt_y_pred, average= 'weighted')
f1 = f1_score(rt_y_test, rt_y_pred, average= 'weighted')

print('-'*35)
print(f'Accuracy = {accuracy}')
print(f'Precision Score = {precision}')
print(f'Recall Score = {recall}')
print(f'F1-score = {f1}')
print('-'*35)
# Out:
# -----------------------------------
# Accuracy = 0.7427395001439172
# Precision Score = 0.6474159176112932
# Recall Score = 0.7427395001439172
# F1-score = 0.6590452108266283
# -----------------------------------

# %% [markdown]
# #### 2e Leave One Out Encoding for Town

# %%
df2_ml_rt_loo = df2_numeric_and_property_done[['Town','Years until sold', 'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type', 'Residential Type']]
df2_ml_rt_loo.head()
# Out:
#              Town  Years until sold  Assessed Value  Sale Amount  Sales Ratio  \
# 58884   Waterford                 1            1000       3500.0      0.28571
# 816649     Hamden                 1         1000000    4150000.0      0.24096
# 678302  Westbrook                 1          100000      80830.0      1.23716
# 719532  East Lyme                 0            1000       4947.0      0.20214
# 470663     Sharon                 1            1000       4000.0      0.25000
#
#        Property Type Residential Type
# 58884    Vacant Land             <NA>
# 816649   Residential              NaN
# 678302   Residential    Single Family
# 719532   Residential              NaN
# 470663   Residential              NaN

# %%
df2_ml_non_nan_rt_loo = df2_ml_rt_loo[df2_ml_rt_loo['Residential Type'].notna()]
df2_ml_non_nan_rt_loo.head()
# Out:
#                Town  Years until sold  Assessed Value  Sale Amount  \
# 678302    Westbrook                 1          100000      80830.0
# 681182    Westbrook                 1           10000      41680.0
# 712586    East Lyme                 0            1000       4617.0
# 379808   Farmington                 0          200000     369318.0
# 267595  North Haven                 1          300000     425000.0
#
#         Sales Ratio Property Type Residential Type
# 678302      1.23716   Residential    Single Family
# 681182      0.23992   Residential    Single Family
# 712586      0.21659   Residential    Single Family
# 379808      0.54154   Residential            Condo
# 267595      0.70588   Residential    Single Family

# %%
loo = TargetEncoder(cv=df2_ml_non_nan_rt_loo.shape[0], random_state=42)

# %%
loo_encode = loo.fit(df2_ml_non_nan_rt_loo[['Town']],df2_ml_non_nan_rt_loo[['Residential Type']])

# %%
loo_encode = loo.transform(df2_ml_non_nan_rt_loo[['Town']])

# %%
df2_ml_non_nan_rt_loo.loc[:,'Town'] = loo_encode[:, 0]

# %%
df2_ml_non_nan_rt_loo
# Out:
#             Town  Years until sold  Assessed Value  Sale Amount  Sales Ratio  \
# 678302       0.0                 1          100000      80830.0      1.23716
# 681182       0.0                 1           10000      41680.0      0.23992
# 712586       0.0                 0            1000       4617.0      0.21659
# 379808  0.000314                 0          200000     369318.0      0.54154
# 267595   0.00021                 1          300000     425000.0      0.70588
# ...          ...               ...             ...          ...          ...
# 307257       0.0                 1          463840     580000.0      0.79972
# 320979       0.0                 1           40314      97000.0      0.41561
# 323184  0.000941                 0          283220     520000.0      0.54465
# 344353       0.0                 0          124110     185000.0      0.67086
# 874940       0.0                 1          171710     390000.0      0.44028
#
#        Property Type Residential Type
# 678302   Residential    Single Family
# 681182   Residential    Single Family
# 712586   Residential    Single Family
# 379808   Residential            Condo
# 267595   Residential    Single Family
# ...              ...              ...
# 307257   Residential    Single Family
# 320979   Residential    Single Family
# 323184   Residential            Condo
# 344353   Residential    Single Family
# 874940   Residential    Single Family
#
# [683263 rows x 7 columns]

# %%
rt_train, rt_test = train_test_split(df2_ml_non_nan_rt_loo.drop('Property Type', axis=1), test_size= 0.6, random_state= 42, shuffle= True)

# %%
rt_train, rt_X_train, rt_y_train = scale_dataset(rt_train, 'Residential Type', oversample= True)
rt_test, rt_X_test, rt_y_test = scale_dataset(rt_test, 'Residential Type', oversample= False)

# %%
random_forest = RandomForestClassifier()

random_forest.fit(rt_X_train, rt_y_train)
rt_y_pred = random_forest.predict(rt_X_test)

# result
accuracy = accuracy_score(rt_y_test, rt_y_pred)
precision = precision_score(rt_y_test, rt_y_pred, average= 'weighted') 
recall = recall_score(rt_y_test, rt_y_pred, average= 'weighted')
f1 = f1_score(rt_y_test, rt_y_pred, average= 'weighted')

print('-'*35)
print(f'Accuracy = {accuracy}')
print(f'Precision Score = {precision}')
print(f'Recall Score = {recall}')
print(f'F1-score = {f1}')
print('-'*35)
# Out:
# -----------------------------------
# Accuracy = 0.7422101776279522
# Precision Score = 0.64646528459318
# Recall Score = 0.7422101776279522
# F1-score = 0.6587428964608252
# -----------------------------------

# %% [markdown]
# #### Since there are no encoding approach that could help to increase the machine learning model score, I will just replace the NaN value for records that are residential to "Unknown"

# %%
df_cleaned =  df2_numeric_and_property_done.drop('Clean Address', axis= 1).copy()
df_cleaned.head()
# Out:
#         Serial Number  List Year Date Recorded       Town         Address  \
# 58884           20323       2020    2021-04-16  Waterford   ROBERTS COURT
# 816649         160511       2016    2017-03-31     Hamden    42 WARNER ST
# 678302         130111       2013    2014-09-04  Westbrook  5 PINE CONE DR
# 719532         140063       2014    2014-11-17  East Lyme        SO TRAIL
# 470663          70022       2007    2008-03-12     Sharon       ROUTE 343
#
#         Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 58884             1000       3500.0      0.28571   Vacant Land
# 816649         1000000    4150000.0      0.24096   Residential
# 678302          100000      80830.0      1.23716   Residential
# 719532            1000       4947.0      0.20214   Residential
# 470663            1000       4000.0      0.25000   Residential
#
#        Residential Type  Years until sold
# 58884              <NA>                 1
# 816649              NaN                 1
# 678302    Single Family                 1
# 719532              NaN                 0
# 470663              NaN                 1

# %%
df_cleaned.shape
# Out:
# (961672, 11)

# %%
df_cleaned.isna().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            0
# Town                     0
# Address                 30
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type            0
# Residential Type    278409
# Years until sold         0
# dtype: int64

# %%
# replace NaN values in the Residential Type with 'Unknown' for records that are residential
df_cleaned.loc[(df_cleaned['Property Type']=='Residential')
           &(df_cleaned['Residential Type'].isna()),'Residential Type'] = 'Unknown'

# %%
# replace NaN values in the Residential Type column with '-' for records that are not residential
df_cleaned.loc[(df_cleaned['Property Type']!='Residential')
           &(df_cleaned['Residential Type'].isna()),'Residential Type'] = '-'

# %%
# replace NaN values in the Address column with 'Unknown'
df_cleaned.loc[df_cleaned['Address'].isna(),'Address'] = 'Unknown'

# %%
df_cleaned.isna().sum()
# Out:
# Serial Number       0
# List Year           0
# Date Recorded       0
# Town                0
# Address             0
# Assessed Value      0
# Sale Amount         0
# Sales Ratio         0
# Property Type       0
# Residential Type    0
# Years until sold    0
# dtype: int64

# %%
df_cleaned.reset_index()
# Out:
#          index  Serial Number  List Year Date Recorded       Town  \
# 0        58884          20323       2020    2021-04-16  Waterford
# 1       816649         160511       2016    2017-03-31     Hamden
# 2       678302         130111       2013    2014-09-04  Westbrook
# 3       719532         140063       2014    2014-11-17  East Lyme
# 4       470663          70022       2007    2008-03-12     Sharon
# ...        ...            ...        ...           ...        ...
# 961667  392655          59999       2005    2006-04-11      Salem
# 961668  392865          50005       2005    2005-10-04     Putnam
# 961669  399530          59000       2005    2005-12-01     Orange
# 961670  406301          59010       2005    2005-11-01      Salem
# 961671  874940         170390       2017    2018-03-19  Greenwich
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0               ROBERTS COURT            1000       3500.0      0.28571
# 1                42 WARNER ST         1000000    4150000.0      0.24096
# 2              5 PINE CONE DR          100000      80830.0      1.23716
# 3                    SO TRAIL            1000       4947.0      0.20214
# 4                   ROUTE 343            1000       4000.0      0.25000
# ...                       ...             ...          ...          ...
# 961667       INDIANFIELD CAMP          215500     235000.0      0.91702
# 961668           224 GROVE ST          137200     205000.0      0.66927
# 961669        40 FARM HILL RD           51870     158500.0      0.32726
# 961670  211 OLD COLCHESTER RD           96460     180000.0      0.53589
# 961671        TWIN LAKES LANE          171710     390000.0      0.44028
#
#        Property Type Residential Type  Years until sold
# 0        Vacant Land                -                 1
# 1        Residential          Unknown                 1
# 2        Residential    Single Family                 1
# 3        Residential          Unknown                 0
# 4        Residential          Unknown                 1
# ...              ...              ...               ...
# 961667   Residential          Unknown                 1
# 961668   Residential          Unknown                 0
# 961669   Residential          Unknown                 0
# 961670   Residential          Unknown                 0
# 961671   Residential    Single Family                 1
#
# [961672 rows x 12 columns]

# %% [markdown]
# # **Save Cleaned Data**

# %%
# Save cleaned data as a CSV file
df_cleaned.to_csv('real_estate_cleaned.csv', index=False)

# %% [markdown]
# -----
